# %%
# public libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
sc.settings.set_figure_params(dpi=100)

# %%
import tensorflow as tf
from tensorflow import keras

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# we'll read both of these values and the original input and irrelevant tcrs
X_cdr3s = pd.read_csv('../outputs/model_v3/cdr3.conversion.n30.csv', index_col=0)
X_epitopes = pd.read_csv('../outputs/model_v3/epitope.conversion.n15.csv', index_col=0)
hit = pd.read_csv('../outputs/model_v3/full.input.X.csv', index_col=0)
irr = pd.read_csv('../outputs/model_v3/full.control.X.csv', index_col=0)
irr = irr.reset_index().iloc[:, 1:]

# %%
# retrieve values and aucs
fprs, tprs, aucs, accs = [], [], [], []

# %%
# assemble hold out
df_ext_X_hit = hit.loc[hit['Epitope'] == 'GILGFVFTL']
df_ext_X_irr = irr.loc[irr['Epitope'] == 'GILGFVFTL']
df_ext_y = pd.concat([pd.Series(np.ones(df_ext_X_hit.shape[0]), index=df_ext_X_hit),
                      pd.Series(np.zeros(df_ext_X_irr.shape[0]), index=df_ext_X_irr)], axis=0)
df_ext_X = pd.concat([df_ext_X_hit, df_ext_X_irr], axis=0).reset_index().iloc[:, 1:]
df_ext_y = df_ext_y.reset_index().iloc[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score

# complete 10 iterations
for seed in range(10):
    # grab a subset
    np.random.seed(seed)
    perc_train = 0.75

    # training and during training testing
    mask_hit = ~(hit['CDR3'].isin(df_ext_X['CDR3']) | hit['Epitope'].isin(df_ext_X['Epitope']))
    mask_irr = ~(irr['CDR3'].isin(df_ext_X['CDR3']) | irr['Epitope'].isin(df_ext_X['Epitope']))
    # > subset target
    idxs = np.random.choice(hit[mask_hit].index, size=sum(mask_hit), replace=False)
    idxs, idys = idxs[:round(sum(mask_hit) * perc_train)], idxs[round(sum(mask_hit) * perc_train):]
    hit_train, hit_test = hit.loc[idxs], hit.loc[idys]
    # > subset control
    idxs = np.random.choice(irr[mask_irr].index, size=sum(mask_irr), replace=False)
    idxs, idys = idxs[:round(sum(mask_irr) * perc_train)], idxs[round(sum(mask_irr) * perc_train):]
    irr_train, irr_test = irr.loc[idxs], irr.loc[idys]

    # create X for training
    X_train = pd.concat([hit_train, irr_train], axis=0).reset_index().iloc[:, 1:]
    cdr3s_training = X_train['CDR3'].unique()
    X_train_cdr3s = X_cdr3s.loc[X_train['CDR3']].reset_index().iloc[:, 1:]
    X_train_epitopes = X_epitopes.loc[X_train['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_train_cdr3s.columns = 'cdr3:' + X_train_cdr3s.columns
    X_train_epitopes.columns = 'ag:' + X_train_epitopes.columns
    X_train = X_train_cdr3s.join(X_train_epitopes)
    # grab y for training
    y_train = pd.concat([pd.Series(np.ones(hit_train.shape[0])), pd.Series(np.zeros(irr_train.shape[0]))], axis=0).astype(int)
    y_train = y_train.reset_index().iloc[:, 1:][0]

    # create X for testing
    X_test = pd.concat([hit_test, irr_test], axis=0).reset_index().iloc[:, 1:]
    X_test_cdr3s = X_cdr3s.loc[X_test['CDR3']].reset_index().iloc[:, 1:]
    X_test_epitopes = X_epitopes.loc[X_test['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_test_cdr3s.columns = 'cdr3:' + X_test_cdr3s.columns
    X_test_epitopes.columns = 'ag:' + X_test_epitopes.columns
    X_test = X_test_cdr3s.join(X_test_epitopes)
    # grab y for testing
    y_test = pd.concat([pd.Series(np.ones(hit_test.shape[0])), pd.Series(np.zeros(irr_test.shape[0]))], axis=0).astype(int)
    y_test = y_test.reset_index().iloc[:, 1:][0]

    # create X for validation
    X_val = df_ext_X.copy().reset_index().iloc[:, 1:]
    X_val_cdr3s = X_cdr3s.loc[X_val['CDR3']].reset_index().iloc[:, 1:]
    X_val_epitopes = X_epitopes.loc[X_val['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_val_cdr3s.columns = 'cdr3:' + X_val_cdr3s.columns
    X_val_epitopes.columns = 'ag:' + X_val_epitopes.columns
    X_val = X_val_cdr3s.join(X_val_epitopes)
    # grab y for validation
    y_val = df_ext_y.copy().reset_index().iloc[:, 1:][0]
    
    print(X_train.shape[0], X_val.shape[0])

    # remove constant columns
    X_train = X_train.loc[:, X_train.nunique(0) > 1]
    X_train = X_train.loc[:, X_train.sum(0) > 0]
    # read in normalization factors
    means = X_train.mean(0)
    stds = (X_train - means).std(0)
    # subset for relevant columns
    X_train = X_train[means.index]
    X_test = X_test[means.index]
    X_val = X_val.T.reindex(means.index).fillna(0).T
    # normalize
    X_train -= means
    X_train /= stds
    X_test -= means
    X_test /= stds
    X_val -= means
    X_val /= stds

    # retrieve the appropriate columns
    cols_cdr3 = X_val.columns[X_val.columns.str.startswith('cdr3')]
    cols_ag = X_val.columns[X_val.columns.str.startswith('ag')]

    # determine model parameters
    # > layer for cdr3 alone
    input_1 = keras.layers.Input(shape=(len(cols_cdr3)))
    output_1 = keras.layers.Dense(200, activation='sigmoid')(input_1)
    # > layer for ag alone
    input_2 = keras.layers.Input(shape=(len(cols_ag)))
    output_2 = keras.layers.Dense(100, activation='sigmoid')(input_2)
    # > combined layer
    concat_3 = keras.layers.Concatenate()([output_1, output_2])
    output_3 = keras.layers.Dense(100, activation='sigmoid')(concat_3)
    # > final logit softmax layer
    output_4 = keras.layers.Dense(1, activation='sigmoid')(output_3)
    model = keras.Model(inputs=[input_1, input_2], outputs=[output_4])
    # set up the training parameters for the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='binary_crossentropy',
        metrics=['accuracy','AUC'],
    )
    # train the model
    history = model.fit([X_train[cols_cdr3], X_train[cols_ag]], y_train,
                        epochs=1,
                        validation_data=([X_val[cols_cdr3], X_val[cols_ag]], y_val),
                        workers=40, use_multiprocessing=True)

    # testing predictions
    y_pred = model.predict([X_val[cols_cdr3], X_val[cols_ag]],
                           workers=40, use_multiprocessing=True)[:, 0]
    y_pred = pd.Series(y_pred, index=y_val.index, name='Pred%')
    y_pred = pd.concat([y_pred, y_val], axis=1)

    # retrieve auc metrics
    fpr, tpr, _ = roc_curve(y_pred[0], y_pred['Pred%'])
    fprs.append(fpr.tolist())
    tprs.append(tpr.tolist())
    aucs.append(auc(fpr, tpr))
    accs.append(accuracy_score(y_pred[0], y_pred['Pred%'].apply(round)))
    print(auc(fpr, tpr))
# Out:
# 112444 20306
# 2023-11-01 10:09:56.453239: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-01 10:09:56.453268: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-01 10:09:56.453578: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3514/3514 [==============================] - 16s 5ms/step - loss: 0.5531 - accuracy: 0.7165 - auc: 0.7316 - val_loss: 0.6339 - val_accuracy: 0.5631 - val_auc: 0.8542
# 635/635 [==============================] - 2s 2ms/step
# 0.8544181062678362
# 112444 20306
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5492 - accuracy: 0.7190 - auc: 0.7370 - val_loss: 0.5806 - val_accuracy: 0.6204 - val_auc: 0.8464
# 635/635 [==============================] - 2s 2ms/step
# 0.8462237887876525
# 112444 20306
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.5541 - accuracy: 0.7171 - auc: 0.7304 - val_loss: 0.6548 - val_accuracy: 0.5302 - val_auc: 0.8686
# 635/635 [==============================] - 1s 2ms/step
# 0.8684111689584311
# 112444 20306
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5527 - accuracy: 0.7159 - auc: 0.7327 - val_loss: 0.6420 - val_accuracy: 0.5564 - val_auc: 0.8429
# 635/635 [==============================] - 2s 2ms/step
# 0.8431650055445173
# 112444 20306
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.5529 - accuracy: 0.7179 - auc: 0.7330 - val_loss: 0.7199 - val_accuracy: 0.5488 - val_auc: 0.8065
# 635/635 [==============================] - 2s 2ms/step
# 0.8064571162907838
# 112444 20306
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5486 - accuracy: 0.7180 - auc: 0.7379 - val_loss: 0.6182 - val_accuracy: 0.5747 - val_auc: 0.8497
# 635/635 [==============================] - 2s 2ms/step
# 0.8494136617703163
# 112444 20306
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.5511 - accuracy: 0.7188 - auc: 0.7342 - val_loss: 0.8105 - val_accuracy: 0.5148 - val_auc: 0.6036
# 635/635 [==============================] - 2s 2ms/step
# 0.6038635210371992
# 112444 20306
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.5517 - accuracy: 0.7187 - auc: 0.7339 - val_loss: 0.6609 - val_accuracy: 0.5697 - val_auc: 0.8492
# 635/635 [==============================] - 2s 2ms/step
# 0.8493223057560891
# 112444 20306
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.5512 - accuracy: 0.7170 - auc: 0.7349 - val_loss: 0.6337 - val_accuracy: 0.5633 - val_auc: 0.8535
# 635/635 [==============================] - 1s 2ms/step
# 0.853409617231456
# 112444 20306
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5506 - accuracy: 0.7173 - auc: 0.7346 - val_loss: 0.6425 - val_accuracy: 0.5676 - val_auc: 0.8514
# 635/635 [==============================] - 1s 2ms/step
# 0.8512221360879848

# %%
# create roc auc curve
fig, ax = plt.subplots(figsize=[4, 4])
ax.grid(False)
# track values to compute mean value
mean_tprs, mean_fpr = [], np.linspace(0, 1, 100)
# plot the individual cv iterations
for fpr, tpr in zip(fprs, tprs):
    # grab the true positive rate when we interpolate
    mean_tprs.append(np.interp(mean_fpr, fpr, tpr))
#     # plot on this individual curve
#     ax.plot(fpr, tpr, color='tab:blue', linestyle='--', linewidth=1, alpha=0.5, zorder=1)
# grab metrics for auc
mean_auc = np.mean(aucs)
ci95_auc = 1.96 * np.std(aucs) / np.sqrt(len(aucs))
# grab metrics for acc
mean_acc = np.mean(accs)
ci95_acc = 1.96 * np.std(accs) / np.sqrt(len(accs))
# plot the average iteration
mean_tpr = np.mean(mean_tprs, axis=0)
ax.plot(mean_fpr, mean_tpr, color='#2D9FC4', linewidth=2,
        label=r'AUC=%0.4f$\pm$%0.4f' % (mean_auc, ci95_auc) + '\n' +
        r'ACC=%0.4f$\pm$%0.4f' % (mean_acc, ci95_acc))
# plot the standard errors (95% CI actually)
ci95_tpr = 1.96 * np.std(mean_tprs, axis=0) / np.sqrt(len(mean_tprs))
mean_tprs_upper = np.minimum(mean_tpr + ci95_tpr, 1)
mean_tprs_lower = np.maximum(mean_tpr - ci95_tpr, 0)
ax.fill_between(mean_fpr, mean_tprs_lower, mean_tprs_upper, color='#2D9FC4', alpha=0.50)
# plot the random line
ax.plot([0,1], [0,1], color='r', linewidth=2, linestyle='--', label='Random')
# add on labels and adjust limits
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.legend(bbox_to_anchor=(1.05,0.99), bbox_transform=ax.transAxes)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
# Out:
# [Text(0.5, 0, 'False Positive Rate'), Text(0, 0.5, 'True Positive Rate')]

# %%
# retrieve values and aucs
fprs, tprs, aucs, accs = [], [], [], []

# %%
# assemble hold out
df_ext_X_hit = hit.loc[hit['Epitope'] == 'GILGFVFTL']
df_ext_X_irr = irr.loc[irr['Epitope'] == 'GILGFVFTL']
df_ext_y = pd.concat([pd.Series(np.ones(df_ext_X_hit.shape[0]), index=df_ext_X_hit),
                      pd.Series(np.zeros(df_ext_X_irr.shape[0]), index=df_ext_X_irr)], axis=0)
df_ext_X = pd.concat([df_ext_X_hit, df_ext_X_irr], axis=0).reset_index().iloc[:, 1:]
df_ext_y = df_ext_y.reset_index().iloc[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score

# complete 10 iterations
for seed in range(10):
    # grab a subset
    np.random.seed(seed)
    perc_train = 0.75

    # training and during training testing
    mask_hit = ~(hit['CDR3'].isin(df_ext_X['CDR3']) | hit['Epitope'].isin(df_ext_X['Epitope']))
    mask_irr = ~(irr['CDR3'].isin(df_ext_X['CDR3']) | irr['Epitope'].isin(df_ext_X['Epitope']))
    # > subset target
    idxs = np.random.choice(hit[mask_hit].index, size=sum(mask_hit), replace=False)
    idxs, idys = idxs[:round(sum(mask_hit) * perc_train)], idxs[round(sum(mask_hit) * perc_train):]
    hit_train, hit_test = hit.loc[idxs], hit.loc[idys]
    # > subset control
    idxs = np.random.choice(irr[mask_irr].index, size=sum(mask_irr), replace=False)
    idxs, idys = idxs[:round(sum(mask_irr) * perc_train)], idxs[round(sum(mask_irr) * perc_train):]
    irr_train, irr_test = irr.loc[idxs], irr.loc[idys]

    # create X for training
    X_train = pd.concat([hit_train, irr_train], axis=0).reset_index().iloc[:, 1:]
    cdr3s_training = X_train['CDR3'].unique()
    X_train_cdr3s = X_cdr3s.loc[X_train['CDR3']].reset_index().iloc[:, 1:]
    X_train_epitopes = X_epitopes.loc[X_train['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_train_cdr3s.columns = 'cdr3:' + X_train_cdr3s.columns
    X_train_epitopes.columns = 'ag:' + X_train_epitopes.columns
    X_train = X_train_cdr3s.join(X_train_epitopes)
    # grab y for training
    y_train = pd.concat([pd.Series(np.ones(hit_train.shape[0])), pd.Series(np.zeros(irr_train.shape[0]))], axis=0).astype(int)
    y_train = y_train.reset_index().iloc[:, 1:][0]

    # create X for testing
    X_test = pd.concat([hit_test, irr_test], axis=0).reset_index().iloc[:, 1:]
    X_test_cdr3s = X_cdr3s.loc[X_test['CDR3']].reset_index().iloc[:, 1:]
    X_test_epitopes = X_epitopes.loc[X_test['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_test_cdr3s.columns = 'cdr3:' + X_test_cdr3s.columns
    X_test_epitopes.columns = 'ag:' + X_test_epitopes.columns
    X_test = X_test_cdr3s.join(X_test_epitopes)
    # grab y for testing
    y_test = pd.concat([pd.Series(np.ones(hit_test.shape[0])), pd.Series(np.zeros(irr_test.shape[0]))], axis=0).astype(int)
    y_test = y_test.reset_index().iloc[:, 1:][0]

    # create X for validation
    X_val = df_ext_X.copy().reset_index().iloc[:, 1:]
    X_val_cdr3s = X_cdr3s.loc[X_val['CDR3']].reset_index().iloc[:, 1:]
    X_val_epitopes = X_epitopes.loc[X_val['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_val_cdr3s.columns = 'cdr3:' + X_val_cdr3s.columns
    X_val_epitopes.columns = 'ag:' + X_val_epitopes.columns
    X_val = X_val_cdr3s.join(X_val_epitopes)
    # grab y for validation
    y_val = df_ext_y.copy().reset_index().iloc[:, 1:][0]
    
    print(X_train.shape[0], X_val.shape[0])

    # remove constant columns
    X_train = X_train.loc[:, X_train.nunique(0) > 1]
    X_train = X_train.loc[:, X_train.sum(0) > 0]
    # read in normalization factors
    means = X_train.mean(0)
    stds = (X_train - means).std(0)
    # subset for relevant columns
    X_train = X_train[means.index]
    X_test = X_test[means.index]
    X_val = X_val.T.reindex(means.index).fillna(0).T
    # normalize
    X_train -= means
    X_train /= stds
    X_test -= means
    X_test /= stds
    X_val -= means
    X_val /= stds

    # retrieve the appropriate columns
    cols_cdr3 = X_val.columns[X_val.columns.str.startswith('cdr3')]
    cols_ag = X_val.columns[X_val.columns.str.startswith('ag')]

    # determine model parameters
    # > layer for cdr3 alone
    input_1 = keras.layers.Input(shape=(len(cols_cdr3)))
    output_1 = keras.layers.Dense(200, activation='sigmoid')(input_1)
    # > layer for ag alone
    input_2 = keras.layers.Input(shape=(len(cols_ag)))
    output_2 = keras.layers.Dense(100, activation='sigmoid')(input_2)
    # > combined layer
    concat_3 = keras.layers.Concatenate()([output_1, output_2])
    output_3 = keras.layers.Dense(100, activation='sigmoid')(concat_3)
    # > final logit softmax layer
    output_4 = keras.layers.Dense(1, activation='sigmoid')(output_3)
    model = keras.Model(inputs=[input_1, input_2], outputs=[output_4])
    # set up the training parameters for the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='binary_crossentropy',
        metrics=['accuracy','AUC'],
    )
    # train the model
    history = model.fit([X_train[cols_cdr3], X_train[cols_ag]], y_train,
                        epochs=5,
                        validation_data=([X_val[cols_cdr3], X_val[cols_ag]], y_val),
                        workers=40, use_multiprocessing=True)

    # testing predictions
    y_pred = model.predict([X_val[cols_cdr3], X_val[cols_ag]],
                           workers=40, use_multiprocessing=True)[:, 0]
    y_pred = pd.Series(y_pred, index=y_val.index, name='Pred%')
    y_pred = pd.concat([y_pred, y_val], axis=1)

    # retrieve auc metrics
    fpr, tpr, _ = roc_curve(y_pred[0], y_pred['Pred%'])
    fprs.append(fpr.tolist())
    tprs.append(tpr.tolist())
    aucs.append(auc(fpr, tpr))
    accs.append(accuracy_score(y_pred[0], y_pred['Pred%'].apply(round)))
    print(auc(fpr, tpr))
# Out:
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5539 - accuracy: 0.7156 - auc: 0.7311 - val_loss: 0.7005 - val_accuracy: 0.5571 - val_auc: 0.8154
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4960 - accuracy: 0.7520 - auc: 0.7983 - val_loss: 0.7160 - val_accuracy: 0.5757 - val_auc: 0.8225
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4364 - accuracy: 0.7934 - auc: 0.8512 - val_loss: 0.8167 - val_accuracy: 0.5854 - val_auc: 0.7412
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3670 - accuracy: 0.8337 - auc: 0.8985 - val_loss: 1.0072 - val_accuracy: 0.5864 - val_auc: 0.5868
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3056 - accuracy: 0.8671 - auc: 0.9307 - val_loss: 1.1158 - val_accuracy: 0.5464 - val_auc: 0.4981
# 635/635 [==============================] - 1s 2ms/step
# 0.49822946325878004
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5517 - accuracy: 0.7173 - auc: 0.7341 - val_loss: 0.6128 - val_accuracy: 0.6673 - val_auc: 0.7826
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4928 - accuracy: 0.7560 - auc: 0.8015 - val_loss: 0.6075 - val_accuracy: 0.6153 - val_auc: 0.8633
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4398 - accuracy: 0.7911 - auc: 0.8487 - val_loss: 0.6196 - val_accuracy: 0.6413 - val_auc: 0.8665
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3767 - accuracy: 0.8309 - auc: 0.8927 - val_loss: 0.5884 - val_accuracy: 0.7028 - val_auc: 0.8489
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3115 - accuracy: 0.8658 - auc: 0.9283 - val_loss: 0.8112 - val_accuracy: 0.6665 - val_auc: 0.8256
# 635/635 [==============================] - 2s 2ms/step
# 0.8257539686758437
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5531 - accuracy: 0.7155 - auc: 0.7321 - val_loss: 0.5716 - val_accuracy: 0.6261 - val_auc: 0.8508
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4913 - accuracy: 0.7553 - auc: 0.8031 - val_loss: 0.5820 - val_accuracy: 0.6319 - val_auc: 0.8702
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4353 - accuracy: 0.7942 - auc: 0.8518 - val_loss: 0.6054 - val_accuracy: 0.6543 - val_auc: 0.8008
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3700 - accuracy: 0.8339 - auc: 0.8968 - val_loss: 0.6646 - val_accuracy: 0.6739 - val_auc: 0.8483
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3069 - accuracy: 0.8663 - auc: 0.9302 - val_loss: 0.9645 - val_accuracy: 0.6310 - val_auc: 0.8152
# 635/635 [==============================] - 1s 2ms/step
# 0.8189230689543001
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5538 - accuracy: 0.7162 - auc: 0.7313 - val_loss: 0.6860 - val_accuracy: 0.5451 - val_auc: 0.8013
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4953 - accuracy: 0.7538 - auc: 0.7991 - val_loss: 0.4971 - val_accuracy: 0.6927 - val_auc: 0.8593
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4399 - accuracy: 0.7911 - auc: 0.8488 - val_loss: 0.6764 - val_accuracy: 0.6239 - val_auc: 0.7490
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3747 - accuracy: 0.8311 - auc: 0.8947 - val_loss: 0.5008 - val_accuracy: 0.7497 - val_auc: 0.8583
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3116 - accuracy: 0.8646 - auc: 0.9288 - val_loss: 0.7519 - val_accuracy: 0.6636 - val_auc: 0.7567
# 635/635 [==============================] - 1s 2ms/step
# 0.7567058901886049
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5533 - accuracy: 0.7155 - auc: 0.7321 - val_loss: 0.6856 - val_accuracy: 0.5651 - val_auc: 0.8662
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4905 - accuracy: 0.7584 - auc: 0.8039 - val_loss: 0.5298 - val_accuracy: 0.6761 - val_auc: 0.8538
# Epoch 3/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.4342 - accuracy: 0.7945 - auc: 0.8523 - val_loss: 0.6093 - val_accuracy: 0.6674 - val_auc: 0.8457
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3695 - accuracy: 0.8347 - auc: 0.8969 - val_loss: 0.7503 - val_accuracy: 0.6455 - val_auc: 0.7316
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3086 - accuracy: 0.8673 - auc: 0.9294 - val_loss: 0.9543 - val_accuracy: 0.5625 - val_auc: 0.5582
# 635/635 [==============================] - 1s 2ms/step
# 0.55811778454845
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 17s 4ms/step - loss: 0.5508 - accuracy: 0.7179 - auc: 0.7358 - val_loss: 0.6710 - val_accuracy: 0.5584 - val_auc: 0.8441
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4921 - accuracy: 0.7543 - auc: 0.8025 - val_loss: 0.5255 - val_accuracy: 0.6651 - val_auc: 0.8589
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4377 - accuracy: 0.7919 - auc: 0.8509 - val_loss: 0.6403 - val_accuracy: 0.6360 - val_auc: 0.8460
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3763 - accuracy: 0.8292 - auc: 0.8935 - val_loss: 0.6574 - val_accuracy: 0.6518 - val_auc: 0.7898
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3150 - accuracy: 0.8619 - auc: 0.9267 - val_loss: 0.9203 - val_accuracy: 0.6303 - val_auc: 0.7617
# 635/635 [==============================] - 1s 2ms/step
# 0.7617509179412891
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5517 - accuracy: 0.7171 - auc: 0.7337 - val_loss: 0.7290 - val_accuracy: 0.5543 - val_auc: 0.8358
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4918 - accuracy: 0.7561 - auc: 0.8026 - val_loss: 0.6349 - val_accuracy: 0.6097 - val_auc: 0.8562
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4352 - accuracy: 0.7939 - auc: 0.8524 - val_loss: 0.7302 - val_accuracy: 0.6151 - val_auc: 0.7984
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3679 - accuracy: 0.8342 - auc: 0.8979 - val_loss: 0.7275 - val_accuracy: 0.6476 - val_auc: 0.7518
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3045 - accuracy: 0.8684 - auc: 0.9312 - val_loss: 0.9528 - val_accuracy: 0.6438 - val_auc: 0.7603
# 635/635 [==============================] - 1s 2ms/step
# 0.7602458131648875
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5536 - accuracy: 0.7167 - auc: 0.7316 - val_loss: 0.7937 - val_accuracy: 0.5172 - val_auc: 0.8410
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4932 - accuracy: 0.7554 - auc: 0.8015 - val_loss: 0.5601 - val_accuracy: 0.6535 - val_auc: 0.8591
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4339 - accuracy: 0.7948 - auc: 0.8531 - val_loss: 0.5736 - val_accuracy: 0.6956 - val_auc: 0.8600
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3649 - accuracy: 0.8349 - auc: 0.8999 - val_loss: 0.6241 - val_accuracy: 0.6884 - val_auc: 0.8201
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3025 - accuracy: 0.8681 - auc: 0.9325 - val_loss: 0.8938 - val_accuracy: 0.6305 - val_auc: 0.8024
# 635/635 [==============================] - 2s 2ms/step
# 0.8022958860084326
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5501 - accuracy: 0.7163 - auc: 0.7359 - val_loss: 0.6948 - val_accuracy: 0.5402 - val_auc: 0.8140
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4916 - accuracy: 0.7546 - auc: 0.8036 - val_loss: 0.6386 - val_accuracy: 0.6046 - val_auc: 0.8413
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4383 - accuracy: 0.7910 - auc: 0.8508 - val_loss: 0.7074 - val_accuracy: 0.6083 - val_auc: 0.7441
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3733 - accuracy: 0.8315 - auc: 0.8956 - val_loss: 0.6047 - val_accuracy: 0.7068 - val_auc: 0.8541
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3106 - accuracy: 0.8645 - auc: 0.9292 - val_loss: 0.9919 - val_accuracy: 0.6387 - val_auc: 0.8322
# 635/635 [==============================] - 1s 2ms/step
# 0.8341926789069841
# 112444 20306
# Epoch 1/5
# 3514/3514 [==============================] - 16s 4ms/step - loss: 0.5532 - accuracy: 0.7158 - auc: 0.7311 - val_loss: 0.6969 - val_accuracy: 0.5437 - val_auc: 0.8529
# Epoch 2/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4923 - accuracy: 0.7559 - auc: 0.8021 - val_loss: 0.5507 - val_accuracy: 0.6889 - val_auc: 0.8246
# Epoch 3/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.4358 - accuracy: 0.7939 - auc: 0.8520 - val_loss: 0.5650 - val_accuracy: 0.6874 - val_auc: 0.8571
# Epoch 4/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3703 - accuracy: 0.8334 - auc: 0.8970 - val_loss: 0.6297 - val_accuracy: 0.6963 - val_auc: 0.8580
# Epoch 5/5
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.3095 - accuracy: 0.8650 - auc: 0.9293 - val_loss: 0.6929 - val_accuracy: 0.6838 - val_auc: 0.8076
# 635/635 [==============================] - 1s 2ms/step
# 0.8077077019202628

# %%
# create roc auc curve
fig, ax = plt.subplots(figsize=[4, 4])
ax.grid(False)
# track values to compute mean value
mean_tprs, mean_fpr = [], np.linspace(0, 1, 100)
# plot the individual cv iterations
for fpr, tpr in zip(fprs, tprs):
    # grab the true positive rate when we interpolate
    mean_tprs.append(np.interp(mean_fpr, fpr, tpr))
#     # plot on this individual curve
#     ax.plot(fpr, tpr, color='tab:blue', linestyle='--', linewidth=1, alpha=0.5, zorder=1)
# grab metrics for auc
mean_auc = np.mean(aucs)
ci95_auc = 1.96 * np.std(aucs) / np.sqrt(len(aucs))
# grab metrics for acc
mean_acc = np.mean(accs)
ci95_acc = 1.96 * np.std(accs) / np.sqrt(len(accs))
# plot the average iteration
mean_tpr = np.mean(mean_tprs, axis=0)
ax.plot(mean_fpr, mean_tpr, color='#2D9FC4', linewidth=2,
        label=r'AUC=%0.4f$\pm$%0.4f' % (mean_auc, ci95_auc) + '\n' +
        r'ACC=%0.4f$\pm$%0.4f' % (mean_acc, ci95_acc))
# plot the standard errors (95% CI actually)
ci95_tpr = 1.96 * np.std(mean_tprs, axis=0) / np.sqrt(len(mean_tprs))
mean_tprs_upper = np.minimum(mean_tpr + ci95_tpr, 1)
mean_tprs_lower = np.maximum(mean_tpr - ci95_tpr, 0)
ax.fill_between(mean_fpr, mean_tprs_lower, mean_tprs_upper, color='#2D9FC4', alpha=0.50)
# plot the random line
ax.plot([0,1], [0,1], color='r', linewidth=2, linestyle='--', label='Random')
# add on labels and adjust limits
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.legend(bbox_to_anchor=(1.05,0.99), bbox_transform=ax.transAxes)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
# Out:
# [Text(0.5, 0, 'False Positive Rate'), Text(0, 0.5, 'True Positive Rate')]

# %%
# retrieve values and aucs
fprs, tprs, aucs, accs = [], [], [], []

# %%
# assemble hold out
df_ext_X_hit = hit.loc[hit['Epitope'] == 'GILGFVFTL']
df_ext_X_irr = irr.loc[irr['Epitope'] == 'GILGFVFTL']
df_ext_y = pd.concat([pd.Series(np.ones(df_ext_X_hit.shape[0]), index=df_ext_X_hit),
                      pd.Series(np.zeros(df_ext_X_irr.shape[0]), index=df_ext_X_irr)], axis=0)
df_ext_X = pd.concat([df_ext_X_hit, df_ext_X_irr], axis=0).reset_index().iloc[:, 1:]
df_ext_y = df_ext_y.reset_index().iloc[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score

# complete 10 iterations
for seed in range(10):
    # grab a subset
    np.random.seed(seed)
    perc_train = 0.75

    # training and during training testing
    mask_hit = ~(hit['CDR3'].isin(df_ext_X['CDR3']) | hit['Epitope'].isin(df_ext_X['Epitope']))
    mask_irr = ~(irr['CDR3'].isin(df_ext_X['CDR3']) | irr['Epitope'].isin(df_ext_X['Epitope']))
    # > subset target
    idxs = np.random.choice(hit[mask_hit].index, size=sum(mask_hit), replace=False)
    idxs, idys = idxs[:round(sum(mask_hit) * perc_train)], idxs[round(sum(mask_hit) * perc_train):]
    hit_train, hit_test = hit.loc[idxs], hit.loc[idys]
    # > subset control
    idxs = np.random.choice(irr[mask_irr].index, size=sum(mask_irr), replace=False)
    idxs, idys = idxs[:round(sum(mask_irr) * perc_train)], idxs[round(sum(mask_irr) * perc_train):]
    irr_train, irr_test = irr.loc[idxs], irr.loc[idys]

    # create X for training
    X_train = pd.concat([hit_train, irr_train], axis=0).reset_index().iloc[:, 1:]
    cdr3s_training = X_train['CDR3'].unique()
    X_train_cdr3s = X_cdr3s.loc[X_train['CDR3']].reset_index().iloc[:, 1:]
    X_train_epitopes = X_epitopes.loc[X_train['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_train_cdr3s.columns = 'cdr3:' + X_train_cdr3s.columns
    X_train_epitopes.columns = 'ag:' + X_train_epitopes.columns
    X_train = X_train_cdr3s.join(X_train_epitopes)
    # grab y for training
    y_train = pd.concat([pd.Series(np.ones(hit_train.shape[0])), pd.Series(np.zeros(irr_train.shape[0]))], axis=0).astype(int)
    y_train = y_train.reset_index().iloc[:, 1:][0]

    # create X for testing
    X_test = pd.concat([hit_test, irr_test], axis=0).reset_index().iloc[:, 1:]
    X_test_cdr3s = X_cdr3s.loc[X_test['CDR3']].reset_index().iloc[:, 1:]
    X_test_epitopes = X_epitopes.loc[X_test['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_test_cdr3s.columns = 'cdr3:' + X_test_cdr3s.columns
    X_test_epitopes.columns = 'ag:' + X_test_epitopes.columns
    X_test = X_test_cdr3s.join(X_test_epitopes)
    # grab y for testing
    y_test = pd.concat([pd.Series(np.ones(hit_test.shape[0])), pd.Series(np.zeros(irr_test.shape[0]))], axis=0).astype(int)
    y_test = y_test.reset_index().iloc[:, 1:][0]

    # create X for validation
    X_val = df_ext_X.copy().reset_index().iloc[:, 1:]
    X_val_cdr3s = X_cdr3s.loc[X_val['CDR3']].reset_index().iloc[:, 1:]
    X_val_epitopes = X_epitopes.loc[X_val['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_val_cdr3s.columns = 'cdr3:' + X_val_cdr3s.columns
    X_val_epitopes.columns = 'ag:' + X_val_epitopes.columns
    X_val = X_val_cdr3s.join(X_val_epitopes)
    # grab y for validation
    y_val = df_ext_y.copy().reset_index().iloc[:, 1:][0]
    
    print(X_train.shape[0], X_val.shape[0])

    # remove constant columns
    X_train = X_train.loc[:, X_train.nunique(0) > 1]
    X_train = X_train.loc[:, X_train.sum(0) > 0]
    # read in normalization factors
    means = X_train.mean(0)
    stds = (X_train - means).std(0)
    # subset for relevant columns
    X_train = X_train[means.index]
    X_test = X_test[means.index]
    X_val = X_val.T.reindex(means.index).fillna(0).T
    # normalize
    X_train -= means
    X_train /= stds
    X_test -= means
    X_test /= stds
    X_val -= means
    X_val /= stds

    # retrieve the appropriate columns
    cols_cdr3 = X_val.columns[X_val.columns.str.startswith('cdr3')]
    cols_ag = X_val.columns[X_val.columns.str.startswith('ag')]

    # determine model parameters
    # > layer for cdr3 alone
    input_1 = keras.layers.Input(shape=(len(cols_cdr3)))
    output_1 = keras.layers.Dense(200, activation='sigmoid')(input_1)
    # > layer for ag alone
    input_2 = keras.layers.Input(shape=(len(cols_ag)))
    output_2 = keras.layers.Dense(100, activation='sigmoid')(input_2)
    # > combined layer
    concat_3 = keras.layers.Concatenate()([output_1, output_2])
    output_3 = keras.layers.Dense(100, activation='sigmoid')(concat_3)
    # > final logit softmax layer
    output_4 = keras.layers.Dense(1, activation='sigmoid')(output_3)
    model = keras.Model(inputs=[input_1, input_2], outputs=[output_4])
    # set up the training parameters for the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='binary_crossentropy',
        metrics=['accuracy','AUC'],
    )
    # train the model
    history = model.fit([X_train[cols_cdr3], X_train[cols_ag]], y_train,
                        epochs=10,
                        validation_data=([X_val[cols_cdr3], X_val[cols_ag]], y_val),
                        workers=40, use_multiprocessing=True)

    # testing predictions
    y_pred = model.predict([X_val[cols_cdr3], X_val[cols_ag]],
                           workers=40, use_multiprocessing=True)[:, 0]
    y_pred = pd.Series(y_pred, index=y_val.index, name='Pred%')
    y_pred = pd.concat([y_pred, y_val], axis=1)

    # retrieve auc metrics
    fpr, tpr, _ = roc_curve(y_pred[0], y_pred['Pred%'])
    fprs.append(fpr.tolist())
    tprs.append(tpr.tolist())
    aucs.append(auc(fpr, tpr))
    accs.append(accuracy_score(y_pred[0], y_pred['Pred%'].apply(round)))
    print(auc(fpr, tpr))
# Out:
# 112444 20306
# 2023-11-01 13:32:29.001175: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-01 13:32:29.001210: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-01 13:32:29.001617: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5530 - accuracy: 0.7160 - auc: 0.7323 - val_loss: 0.7719 - val_accuracy: 0.5154 - val_auc: 0.8314
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4960 - accuracy: 0.7527 - auc: 0.7989 - val_loss: 0.6714 - val_accuracy: 0.5860 - val_auc: 0.8285
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4425 - accuracy: 0.7897 - auc: 0.8465 - val_loss: 0.6705 - val_accuracy: 0.6277 - val_auc: 0.6794
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3796 - accuracy: 0.8280 - auc: 0.8908 - val_loss: 0.7080 - val_accuracy: 0.6304 - val_auc: 0.7325
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3154 - accuracy: 0.8610 - auc: 0.9263 - val_loss: 1.0670 - val_accuracy: 0.5146 - val_auc: 0.5082
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2651 - accuracy: 0.8867 - auc: 0.9484 - val_loss: 1.0417 - val_accuracy: 0.6013 - val_auc: 0.6668
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2268 - accuracy: 0.9054 - auc: 0.9622 - val_loss: 1.4856 - val_accuracy: 0.4201 - val_auc: 0.3783
# Epoch 8/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1962 - accuracy: 0.9194 - auc: 0.9717 - val_loss: 1.2904 - val_accuracy: 0.4784 - val_auc: 0.4702
# Epoch 9/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1732 - accuracy: 0.9304 - auc: 0.9780 - val_loss: 1.7613 - val_accuracy: 0.4023 - val_auc: 0.3589
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1548 - accuracy: 0.9378 - auc: 0.9824 - val_loss: 1.3578 - val_accuracy: 0.5451 - val_auc: 0.5373
# 635/635 [==============================] - 2s 2ms/step
# 0.5369064073920943
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5504 - accuracy: 0.7180 - auc: 0.7356 - val_loss: 0.6308 - val_accuracy: 0.5738 - val_auc: 0.8672
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4933 - accuracy: 0.7536 - auc: 0.8017 - val_loss: 0.4764 - val_accuracy: 0.7347 - val_auc: 0.8714
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4395 - accuracy: 0.7908 - auc: 0.8489 - val_loss: 0.5259 - val_accuracy: 0.6933 - val_auc: 0.8596
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3763 - accuracy: 0.8293 - auc: 0.8933 - val_loss: 0.6294 - val_accuracy: 0.6633 - val_auc: 0.7855
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3129 - accuracy: 0.8628 - auc: 0.9277 - val_loss: 0.7553 - val_accuracy: 0.6789 - val_auc: 0.7231
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2641 - accuracy: 0.8876 - auc: 0.9489 - val_loss: 0.9112 - val_accuracy: 0.6296 - val_auc: 0.6694
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2248 - accuracy: 0.9071 - auc: 0.9630 - val_loss: 1.3191 - val_accuracy: 0.5942 - val_auc: 0.5513
# Epoch 8/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1942 - accuracy: 0.9204 - auc: 0.9724 - val_loss: 1.3409 - val_accuracy: 0.5278 - val_auc: 0.5280
# Epoch 9/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1711 - accuracy: 0.9303 - auc: 0.9787 - val_loss: 1.4488 - val_accuracy: 0.5290 - val_auc: 0.4932
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1525 - accuracy: 0.9384 - auc: 0.9830 - val_loss: 1.6075 - val_accuracy: 0.4617 - val_auc: 0.4776
# 635/635 [==============================] - 2s 2ms/step
# 0.4781149893524782
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5515 - accuracy: 0.7146 - auc: 0.7332 - val_loss: 0.7106 - val_accuracy: 0.5234 - val_auc: 0.8615
# Epoch 2/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.4924 - accuracy: 0.7545 - auc: 0.8017 - val_loss: 0.5812 - val_accuracy: 0.6366 - val_auc: 0.8424
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4384 - accuracy: 0.7897 - auc: 0.8496 - val_loss: 0.6486 - val_accuracy: 0.6421 - val_auc: 0.8328
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3729 - accuracy: 0.8302 - auc: 0.8954 - val_loss: 0.7591 - val_accuracy: 0.6563 - val_auc: 0.8166
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3098 - accuracy: 0.8648 - auc: 0.9289 - val_loss: 1.0766 - val_accuracy: 0.6184 - val_auc: 0.7693
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2601 - accuracy: 0.8889 - auc: 0.9505 - val_loss: 1.0992 - val_accuracy: 0.6616 - val_auc: 0.7720
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2234 - accuracy: 0.9057 - auc: 0.9636 - val_loss: 1.6577 - val_accuracy: 0.6098 - val_auc: 0.7038
# Epoch 8/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1950 - accuracy: 0.9198 - auc: 0.9722 - val_loss: 1.7945 - val_accuracy: 0.6206 - val_auc: 0.6719
# Epoch 9/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1716 - accuracy: 0.9299 - auc: 0.9787 - val_loss: 1.6517 - val_accuracy: 0.6501 - val_auc: 0.7328
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1538 - accuracy: 0.9377 - auc: 0.9829 - val_loss: 1.5934 - val_accuracy: 0.6651 - val_auc: 0.7596
# 635/635 [==============================] - 2s 3ms/step
# 0.7767650621280606
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5540 - accuracy: 0.7162 - auc: 0.7307 - val_loss: 0.6694 - val_accuracy: 0.5857 - val_auc: 0.7592
# Epoch 2/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.4982 - accuracy: 0.7519 - auc: 0.7960 - val_loss: 0.5951 - val_accuracy: 0.6350 - val_auc: 0.8102
# Epoch 3/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.4388 - accuracy: 0.7905 - auc: 0.8495 - val_loss: 0.6858 - val_accuracy: 0.6341 - val_auc: 0.8403
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3686 - accuracy: 0.8341 - auc: 0.8977 - val_loss: 0.6741 - val_accuracy: 0.6788 - val_auc: 0.8144
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3042 - accuracy: 0.8683 - auc: 0.9318 - val_loss: 0.8489 - val_accuracy: 0.6470 - val_auc: 0.6935
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2550 - accuracy: 0.8925 - auc: 0.9524 - val_loss: 1.1742 - val_accuracy: 0.5161 - val_auc: 0.4838
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2187 - accuracy: 0.9097 - auc: 0.9650 - val_loss: 1.0504 - val_accuracy: 0.6611 - val_auc: 0.7447
# Epoch 8/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1884 - accuracy: 0.9236 - auc: 0.9740 - val_loss: 1.2805 - val_accuracy: 0.6403 - val_auc: 0.6920
# Epoch 9/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1668 - accuracy: 0.9334 - auc: 0.9796 - val_loss: 1.5384 - val_accuracy: 0.6431 - val_auc: 0.7082
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1489 - accuracy: 0.9405 - auc: 0.9838 - val_loss: 1.5786 - val_accuracy: 0.6484 - val_auc: 0.7023
# 635/635 [==============================] - 1s 2ms/step
# 0.699714135628365
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5523 - accuracy: 0.7161 - auc: 0.7332 - val_loss: 0.7272 - val_accuracy: 0.5376 - val_auc: 0.8698
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4915 - accuracy: 0.7554 - auc: 0.8032 - val_loss: 0.7994 - val_accuracy: 0.5539 - val_auc: 0.5752
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4371 - accuracy: 0.7930 - auc: 0.8507 - val_loss: 0.7133 - val_accuracy: 0.6144 - val_auc: 0.7676
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3739 - accuracy: 0.8311 - auc: 0.8947 - val_loss: 0.8453 - val_accuracy: 0.6260 - val_auc: 0.7935
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3130 - accuracy: 0.8633 - auc: 0.9276 - val_loss: 0.8164 - val_accuracy: 0.6434 - val_auc: 0.7580
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2617 - accuracy: 0.8893 - auc: 0.9500 - val_loss: 1.1770 - val_accuracy: 0.6022 - val_auc: 0.6677
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2243 - accuracy: 0.9069 - auc: 0.9633 - val_loss: 1.2361 - val_accuracy: 0.6172 - val_auc: 0.6496
# Epoch 8/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1936 - accuracy: 0.9209 - auc: 0.9727 - val_loss: 1.4920 - val_accuracy: 0.6161 - val_auc: 0.7104
# Epoch 9/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1697 - accuracy: 0.9316 - auc: 0.9790 - val_loss: 1.8469 - val_accuracy: 0.6090 - val_auc: 0.7014
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1501 - accuracy: 0.9404 - auc: 0.9835 - val_loss: 2.0031 - val_accuracy: 0.6158 - val_auc: 0.7049
# 635/635 [==============================] - 2s 2ms/step
# 0.7283242819567284
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5493 - accuracy: 0.7178 - auc: 0.7380 - val_loss: 0.7394 - val_accuracy: 0.5310 - val_auc: 0.8037
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4878 - accuracy: 0.7600 - auc: 0.8068 - val_loss: 0.5796 - val_accuracy: 0.6346 - val_auc: 0.8825
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4326 - accuracy: 0.7961 - auc: 0.8541 - val_loss: 0.7203 - val_accuracy: 0.6062 - val_auc: 0.6453
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3647 - accuracy: 0.8364 - auc: 0.8999 - val_loss: 0.7461 - val_accuracy: 0.6431 - val_auc: 0.7724
# Epoch 5/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.3008 - accuracy: 0.8700 - auc: 0.9332 - val_loss: 0.8787 - val_accuracy: 0.6205 - val_auc: 0.6252
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2512 - accuracy: 0.8945 - auc: 0.9536 - val_loss: 1.2426 - val_accuracy: 0.5363 - val_auc: 0.4838
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2158 - accuracy: 0.9103 - auc: 0.9657 - val_loss: 1.4719 - val_accuracy: 0.5885 - val_auc: 0.5800
# Epoch 8/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1879 - accuracy: 0.9235 - auc: 0.9738 - val_loss: 1.5977 - val_accuracy: 0.5852 - val_auc: 0.5560
# Epoch 9/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1675 - accuracy: 0.9332 - auc: 0.9793 - val_loss: 1.5386 - val_accuracy: 0.6069 - val_auc: 0.5993
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1487 - accuracy: 0.9409 - auc: 0.9835 - val_loss: 2.0033 - val_accuracy: 0.5336 - val_auc: 0.4376
# 635/635 [==============================] - 2s 2ms/step
# 0.4344711159603894
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5517 - accuracy: 0.7170 - auc: 0.7345 - val_loss: 0.6500 - val_accuracy: 0.5832 - val_auc: 0.8795
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4929 - accuracy: 0.7547 - auc: 0.8015 - val_loss: 0.7051 - val_accuracy: 0.5897 - val_auc: 0.8853
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4384 - accuracy: 0.7927 - auc: 0.8499 - val_loss: 0.8348 - val_accuracy: 0.6040 - val_auc: 0.8447
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3738 - accuracy: 0.8318 - auc: 0.8942 - val_loss: 0.9312 - val_accuracy: 0.5804 - val_auc: 0.6474
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3108 - accuracy: 0.8649 - auc: 0.9283 - val_loss: 1.2654 - val_accuracy: 0.5727 - val_auc: 0.5700
# Epoch 6/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.2603 - accuracy: 0.8899 - auc: 0.9501 - val_loss: 1.2924 - val_accuracy: 0.5936 - val_auc: 0.5981
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2223 - accuracy: 0.9085 - auc: 0.9636 - val_loss: 1.6096 - val_accuracy: 0.5886 - val_auc: 0.6562
# Epoch 8/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1947 - accuracy: 0.9204 - auc: 0.9720 - val_loss: 1.9666 - val_accuracy: 0.5896 - val_auc: 0.5862
# Epoch 9/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1723 - accuracy: 0.9304 - auc: 0.9782 - val_loss: 2.0099 - val_accuracy: 0.5852 - val_auc: 0.6114
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1537 - accuracy: 0.9385 - auc: 0.9826 - val_loss: 2.3420 - val_accuracy: 0.5875 - val_auc: 0.6301
# 635/635 [==============================] - 2s 2ms/step
# 0.6342314514499265
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5531 - accuracy: 0.7186 - auc: 0.7324 - val_loss: 0.6490 - val_accuracy: 0.5924 - val_auc: 0.8366
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4888 - accuracy: 0.7608 - auc: 0.8055 - val_loss: 0.6296 - val_accuracy: 0.6234 - val_auc: 0.8304
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4317 - accuracy: 0.7976 - auc: 0.8547 - val_loss: 0.5511 - val_accuracy: 0.6766 - val_auc: 0.8437
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3662 - accuracy: 0.8362 - auc: 0.8986 - val_loss: 0.6698 - val_accuracy: 0.6576 - val_auc: 0.7725
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3050 - accuracy: 0.8689 - auc: 0.9311 - val_loss: 0.9450 - val_accuracy: 0.6227 - val_auc: 0.7346
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2569 - accuracy: 0.8925 - auc: 0.9513 - val_loss: 1.1705 - val_accuracy: 0.6040 - val_auc: 0.6751
# Epoch 7/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.2193 - accuracy: 0.9110 - auc: 0.9643 - val_loss: 1.3382 - val_accuracy: 0.6136 - val_auc: 0.6314
# Epoch 8/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1930 - accuracy: 0.9208 - auc: 0.9725 - val_loss: 1.3575 - val_accuracy: 0.6150 - val_auc: 0.5885
# Epoch 9/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1708 - accuracy: 0.9308 - auc: 0.9785 - val_loss: 1.8933 - val_accuracy: 0.5546 - val_auc: 0.4761
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1507 - accuracy: 0.9395 - auc: 0.9833 - val_loss: 2.1520 - val_accuracy: 0.5008 - val_auc: 0.4359
# 635/635 [==============================] - 2s 2ms/step
# 0.43231393633351356
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5501 - accuracy: 0.7174 - auc: 0.7365 - val_loss: 0.6298 - val_accuracy: 0.5806 - val_auc: 0.8612
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4895 - accuracy: 0.7567 - auc: 0.8057 - val_loss: 0.5650 - val_accuracy: 0.6477 - val_auc: 0.8698
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4341 - accuracy: 0.7946 - auc: 0.8535 - val_loss: 0.5913 - val_accuracy: 0.6708 - val_auc: 0.8640
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3687 - accuracy: 0.8336 - auc: 0.8981 - val_loss: 0.6258 - val_accuracy: 0.6914 - val_auc: 0.8300
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3053 - accuracy: 0.8676 - auc: 0.9312 - val_loss: 1.0280 - val_accuracy: 0.5858 - val_auc: 0.6016
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2565 - accuracy: 0.8925 - auc: 0.9515 - val_loss: 1.4052 - val_accuracy: 0.5948 - val_auc: 0.5887
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2181 - accuracy: 0.9099 - auc: 0.9650 - val_loss: 1.7988 - val_accuracy: 0.5809 - val_auc: 0.5669
# Epoch 8/10
# 3514/3514 [==============================] - 13s 4ms/step - loss: 0.1904 - accuracy: 0.9219 - auc: 0.9733 - val_loss: 1.5987 - val_accuracy: 0.6017 - val_auc: 0.5891
# Epoch 9/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1698 - accuracy: 0.9316 - auc: 0.9786 - val_loss: 2.2750 - val_accuracy: 0.5554 - val_auc: 0.4986
# Epoch 10/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1516 - accuracy: 0.9395 - auc: 0.9831 - val_loss: 2.3789 - val_accuracy: 0.5840 - val_auc: 0.5727
# 635/635 [==============================] - 2s 2ms/step
# 0.5604559625806853
# 112444 20306
# Epoch 1/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.5521 - accuracy: 0.7182 - auc: 0.7327 - val_loss: 0.7547 - val_accuracy: 0.5149 - val_auc: 0.8740
# Epoch 2/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4943 - accuracy: 0.7533 - auc: 0.7993 - val_loss: 0.5575 - val_accuracy: 0.6536 - val_auc: 0.8784
# Epoch 3/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.4377 - accuracy: 0.7920 - auc: 0.8505 - val_loss: 0.4847 - val_accuracy: 0.7431 - val_auc: 0.8620
# Epoch 4/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3702 - accuracy: 0.8334 - auc: 0.8965 - val_loss: 0.6084 - val_accuracy: 0.6930 - val_auc: 0.8389
# Epoch 5/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.3072 - accuracy: 0.8672 - auc: 0.9299 - val_loss: 0.8654 - val_accuracy: 0.6667 - val_auc: 0.7954
# Epoch 6/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2582 - accuracy: 0.8905 - auc: 0.9509 - val_loss: 1.0397 - val_accuracy: 0.6654 - val_auc: 0.8178
# Epoch 7/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.2204 - accuracy: 0.9085 - auc: 0.9642 - val_loss: 1.3805 - val_accuracy: 0.6367 - val_auc: 0.7379
# Epoch 8/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.1926 - accuracy: 0.9204 - auc: 0.9727 - val_loss: 1.2486 - val_accuracy: 0.6676 - val_auc: 0.7380
# Epoch 9/10
# 3514/3514 [==============================] - 14s 4ms/step - loss: 0.1707 - accuracy: 0.9302 - auc: 0.9786 - val_loss: 1.7944 - val_accuracy: 0.6240 - val_auc: 0.6659
# Epoch 10/10
# 3514/3514 [==============================] - 15s 4ms/step - loss: 0.1523 - accuracy: 0.9391 - auc: 0.9829 - val_loss: 1.8891 - val_accuracy: 0.6190 - val_auc: 0.6998
# 635/635 [==============================] - 2s 2ms/step
# 0.6992646420962242

# %%
# create roc auc curve
fig, ax = plt.subplots(figsize=[4, 4])
ax.grid(False)
# track values to compute mean value
mean_tprs, mean_fpr = [], np.linspace(0, 1, 100)
# plot the individual cv iterations
for fpr, tpr in zip(fprs, tprs):
    # grab the true positive rate when we interpolate
    mean_tprs.append(np.interp(mean_fpr, fpr, tpr))
#     # plot on this individual curve
#     ax.plot(fpr, tpr, color='tab:blue', linestyle='--', linewidth=1, alpha=0.5, zorder=1)
# grab metrics for auc
mean_auc = np.mean(aucs)
ci95_auc = 1.96 * np.std(aucs) / np.sqrt(len(aucs))
# grab metrics for acc
mean_acc = np.mean(accs)
ci95_acc = 1.96 * np.std(accs) / np.sqrt(len(accs))
# plot the average iteration
mean_tpr = np.mean(mean_tprs, axis=0)
ax.plot(mean_fpr, mean_tpr, color='#2D9FC4', linewidth=2,
        label=r'AUC=%0.4f$\pm$%0.4f' % (mean_auc, ci95_auc) + '\n' +
        r'ACC=%0.4f$\pm$%0.4f' % (mean_acc, ci95_acc))
# plot the standard errors (95% CI actually)
ci95_tpr = 1.96 * np.std(mean_tprs, axis=0) / np.sqrt(len(mean_tprs))
mean_tprs_upper = np.minimum(mean_tpr + ci95_tpr, 1)
mean_tprs_lower = np.maximum(mean_tpr - ci95_tpr, 0)
ax.fill_between(mean_fpr, mean_tprs_lower, mean_tprs_upper, color='#2D9FC4', alpha=0.50)
# plot the random line
ax.plot([0,1], [0,1], color='r', linewidth=2, linestyle='--', label='Random')
# add on labels and adjust limits
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.legend(bbox_to_anchor=(1.05,0.99), bbox_transform=ax.transAxes)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
# Out:
# [Text(0.5, 0, 'False Positive Rate'), Text(0, 0.5, 'True Positive Rate')]
