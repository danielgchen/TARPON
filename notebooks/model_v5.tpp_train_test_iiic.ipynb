# %%
# public libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
sc.settings.set_figure_params(dpi=100)

# %%
import tensorflow as tf
from tensorflow import keras

# %load_ext tensorboard
# Out:
# 2023-11-01 13:31:49.247390: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-01 13:31:49.401827: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-01 13:31:50.034388: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-11-01 13:31:50.034486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-11-01 13:31:50.034495: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# we'll read both of these values and the original input and irrelevant tcrs
X_cdr3s = pd.read_csv('../outputs/model_v3/cdr3.conversion.n30.csv', index_col=0)
X_epitopes = pd.read_csv('../outputs/model_v3/epitope.conversion.n15.csv', index_col=0)
hit = pd.read_csv('../outputs/model_v3/full.input.X.csv', index_col=0)
irr = pd.read_csv('../outputs/model_v3/full.control.X.csv', index_col=0)
irr = irr.reset_index().iloc[:, 1:]

# %%
# retrieve values and aucs
fprs, tprs, aucs, accs = [], [], [], []

# %%
# assemble hold out
df_ext_X_hit = hit.loc[hit['Epitope'] == 'GLCTLVAML']
df_ext_X_irr = irr.loc[irr['Epitope'] == 'GLCTLVAML']
df_ext_y = pd.concat([pd.Series(np.ones(df_ext_X_hit.shape[0]), index=df_ext_X_hit),
                      pd.Series(np.zeros(df_ext_X_irr.shape[0]), index=df_ext_X_irr)], axis=0)
df_ext_X = pd.concat([df_ext_X_hit, df_ext_X_irr], axis=0).reset_index().iloc[:, 1:]
df_ext_y = df_ext_y.reset_index().iloc[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score

# complete 10 iterations
for seed in range(10):
    # grab a subset
    np.random.seed(seed)
    perc_train = 0.75

    # training and during training testing
    mask_hit = ~(hit['CDR3'].isin(df_ext_X['CDR3']) | hit['Epitope'].isin(df_ext_X['Epitope']))
    mask_irr = ~(irr['CDR3'].isin(df_ext_X['CDR3']) | irr['Epitope'].isin(df_ext_X['Epitope']))
    # > subset target
    idxs = np.random.choice(hit[mask_hit].index, size=sum(mask_hit), replace=False)
    idxs, idys = idxs[:round(sum(mask_hit) * perc_train)], idxs[round(sum(mask_hit) * perc_train):]
    hit_train, hit_test = hit.loc[idxs], hit.loc[idys]
    # > subset control
    idxs = np.random.choice(irr[mask_irr].index, size=sum(mask_irr), replace=False)
    idxs, idys = idxs[:round(sum(mask_irr) * perc_train)], idxs[round(sum(mask_irr) * perc_train):]
    irr_train, irr_test = irr.loc[idxs], irr.loc[idys]

    # create X for training
    X_train = pd.concat([hit_train, irr_train], axis=0).reset_index().iloc[:, 1:]
    cdr3s_training = X_train['CDR3'].unique()
    X_train_cdr3s = X_cdr3s.loc[X_train['CDR3']].reset_index().iloc[:, 1:]
    X_train_epitopes = X_epitopes.loc[X_train['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_train_cdr3s.columns = 'cdr3:' + X_train_cdr3s.columns
    X_train_epitopes.columns = 'ag:' + X_train_epitopes.columns
    X_train = X_train_cdr3s.join(X_train_epitopes)
    # grab y for training
    y_train = pd.concat([pd.Series(np.ones(hit_train.shape[0])), pd.Series(np.zeros(irr_train.shape[0]))], axis=0).astype(int)
    y_train = y_train.reset_index().iloc[:, 1:][0]

    # create X for testing
    X_test = pd.concat([hit_test, irr_test], axis=0).reset_index().iloc[:, 1:]
    X_test_cdr3s = X_cdr3s.loc[X_test['CDR3']].reset_index().iloc[:, 1:]
    X_test_epitopes = X_epitopes.loc[X_test['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_test_cdr3s.columns = 'cdr3:' + X_test_cdr3s.columns
    X_test_epitopes.columns = 'ag:' + X_test_epitopes.columns
    X_test = X_test_cdr3s.join(X_test_epitopes)
    # grab y for testing
    y_test = pd.concat([pd.Series(np.ones(hit_test.shape[0])), pd.Series(np.zeros(irr_test.shape[0]))], axis=0).astype(int)
    y_test = y_test.reset_index().iloc[:, 1:][0]

    # create X for validation
    X_val = df_ext_X.copy().reset_index().iloc[:, 1:]
    X_val_cdr3s = X_cdr3s.loc[X_val['CDR3']].reset_index().iloc[:, 1:]
    X_val_epitopes = X_epitopes.loc[X_val['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_val_cdr3s.columns = 'cdr3:' + X_val_cdr3s.columns
    X_val_epitopes.columns = 'ag:' + X_val_epitopes.columns
    X_val = X_val_cdr3s.join(X_val_epitopes)
    # grab y for validation
    y_val = df_ext_y.copy().reset_index().iloc[:, 1:][0]
    
    print(X_train.shape[0], X_val.shape[0])

    # remove constant columns
    X_train = X_train.loc[:, X_train.nunique(0) > 1]
    X_train = X_train.loc[:, X_train.sum(0) > 0]
    # read in normalization factors
    means = X_train.mean(0)
    stds = (X_train - means).std(0)
    # subset for relevant columns
    X_train = X_train[means.index]
    X_test = X_test[means.index]
    X_val = X_val.T.reindex(means.index).fillna(0).T
    # normalize
    X_train -= means
    X_train /= stds
    X_test -= means
    X_test /= stds
    X_val -= means
    X_val /= stds

    # retrieve the appropriate columns
    cols_cdr3 = X_val.columns[X_val.columns.str.startswith('cdr3')]
    cols_ag = X_val.columns[X_val.columns.str.startswith('ag')]

    # determine model parameters
    # > layer for cdr3 alone
    input_1 = keras.layers.Input(shape=(len(cols_cdr3)))
    output_1 = keras.layers.Dense(200, activation='sigmoid')(input_1)
    # > layer for ag alone
    input_2 = keras.layers.Input(shape=(len(cols_ag)))
    output_2 = keras.layers.Dense(100, activation='sigmoid')(input_2)
    # > combined layer
    concat_3 = keras.layers.Concatenate()([output_1, output_2])
    output_3 = keras.layers.Dense(100, activation='sigmoid')(concat_3)
    # > final logit softmax layer
    output_4 = keras.layers.Dense(1, activation='sigmoid')(output_3)
    model = keras.Model(inputs=[input_1, input_2], outputs=[output_4])
    # set up the training parameters for the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='binary_crossentropy',
        metrics=['accuracy','AUC'],
    )
    # train the model
    history = model.fit([X_train[cols_cdr3], X_train[cols_ag]], y_train,
                        epochs=1,
                        validation_data=([X_val[cols_cdr3], X_val[cols_ag]], y_val),
                        workers=40, use_multiprocessing=True)

    # testing predictions
    y_pred = model.predict([X_val[cols_cdr3], X_val[cols_ag]],
                           workers=40, use_multiprocessing=True)[:, 0]
    y_pred = pd.Series(y_pred, index=y_val.index, name='Pred%')
    y_pred = pd.concat([y_pred, y_val], axis=1)

    # retrieve auc metrics
    fpr, tpr, _ = roc_curve(y_pred[0], y_pred['Pred%'])
    fprs.append(fpr.tolist())
    tprs.append(tpr.tolist())
    aucs.append(auc(fpr, tpr))
    accs.append(accuracy_score(y_pred[0], y_pred['Pred%'].apply(round)))
    print(auc(fpr, tpr))
# Out:
# 109785 21596
# 2023-11-01 10:10:58.425404: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-01 10:10:58.425439: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-01 10:10:58.425836: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4900 - accuracy: 0.7687 - auc: 0.7816 - val_loss: 0.7938 - val_accuracy: 0.5310 - val_auc: 0.6695
# 675/675 [==============================] - 1s 2ms/step
# 0.6695083674664601
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4906 - accuracy: 0.7689 - auc: 0.7817 - val_loss: 0.7026 - val_accuracy: 0.5803 - val_auc: 0.6700
# 675/675 [==============================] - 1s 2ms/step
# 0.670158392966202
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4920 - accuracy: 0.7689 - auc: 0.7800 - val_loss: 0.8161 - val_accuracy: 0.5280 - val_auc: 0.6787
# 675/675 [==============================] - 1s 2ms/step
# 0.6787914286000141
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4908 - accuracy: 0.7673 - auc: 0.7815 - val_loss: 0.8230 - val_accuracy: 0.5223 - val_auc: 0.6565
# 675/675 [==============================] - 1s 2ms/step
# 0.6565197775328402
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4916 - accuracy: 0.7679 - auc: 0.7801 - val_loss: 0.7110 - val_accuracy: 0.5789 - val_auc: 0.6492
# 675/675 [==============================] - 1s 2ms/step
# 0.6493678223873092
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4943 - accuracy: 0.7670 - auc: 0.7772 - val_loss: 0.9007 - val_accuracy: 0.5239 - val_auc: 0.6775
# 675/675 [==============================] - 2s 2ms/step
# 0.6778733391299068
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4923 - accuracy: 0.7670 - auc: 0.7798 - val_loss: 0.9092 - val_accuracy: 0.5214 - val_auc: 0.6567
# 675/675 [==============================] - 2s 2ms/step
# 0.6569492604301931
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4917 - accuracy: 0.7684 - auc: 0.7808 - val_loss: 0.8904 - val_accuracy: 0.5183 - val_auc: 0.6642
# 675/675 [==============================] - 2s 2ms/step
# 0.6640790543956279
# 109785 21596
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4920 - accuracy: 0.7680 - auc: 0.7806 - val_loss: 0.7168 - val_accuracy: 0.5918 - val_auc: 0.6864
# 675/675 [==============================] - 2s 2ms/step
# 0.6864843252268472
# 109785 21596
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4931 - accuracy: 0.7675 - auc: 0.7792 - val_loss: 0.7356 - val_accuracy: 0.5816 - val_auc: 0.6806
# 675/675 [==============================] - 2s 2ms/step
# 0.6806691302318645

# %%
# create roc auc curve
fig, ax = plt.subplots(figsize=[4, 4])
ax.grid(False)
# track values to compute mean value
mean_tprs, mean_fpr = [], np.linspace(0, 1, 100)
# plot the individual cv iterations
for fpr, tpr in zip(fprs, tprs):
    # grab the true positive rate when we interpolate
    mean_tprs.append(np.interp(mean_fpr, fpr, tpr))
#     # plot on this individual curve
#     ax.plot(fpr, tpr, color='tab:blue', linestyle='--', linewidth=1, alpha=0.5, zorder=1)
# grab metrics for auc
mean_auc = np.mean(aucs)
ci95_auc = 1.96 * np.std(aucs) / np.sqrt(len(aucs))
# grab metrics for acc
mean_acc = np.mean(accs)
ci95_acc = 1.96 * np.std(accs) / np.sqrt(len(accs))
# plot the average iteration
mean_tpr = np.mean(mean_tprs, axis=0)
ax.plot(mean_fpr, mean_tpr, color='#2D9FC4', linewidth=2,
        label=r'AUC=%0.4f$\pm$%0.4f' % (mean_auc, ci95_auc) + '\n' +
        r'ACC=%0.4f$\pm$%0.4f' % (mean_acc, ci95_acc))
# plot the standard errors (95% CI actually)
ci95_tpr = 1.96 * np.std(mean_tprs, axis=0) / np.sqrt(len(mean_tprs))
mean_tprs_upper = np.minimum(mean_tpr + ci95_tpr, 1)
mean_tprs_lower = np.maximum(mean_tpr - ci95_tpr, 0)
ax.fill_between(mean_fpr, mean_tprs_lower, mean_tprs_upper, color='#2D9FC4', alpha=0.50)
# plot the random line
ax.plot([0,1], [0,1], color='r', linewidth=2, linestyle='--', label='Random')
# add on labels and adjust limits
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.legend(bbox_to_anchor=(1.05,0.99), bbox_transform=ax.transAxes)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
# Out:
# [Text(0.5, 0, 'False Positive Rate'), Text(0, 0.5, 'True Positive Rate')]

# %%
# retrieve values and aucs
fprs, tprs, aucs, accs = [], [], [], []

# %%
# assemble hold out
df_ext_X_hit = hit.loc[hit['Epitope'] == 'GLCTLVAML']
df_ext_X_irr = irr.loc[irr['Epitope'] == 'GLCTLVAML']
df_ext_y = pd.concat([pd.Series(np.ones(df_ext_X_hit.shape[0]), index=df_ext_X_hit),
                      pd.Series(np.zeros(df_ext_X_irr.shape[0]), index=df_ext_X_irr)], axis=0)
df_ext_X = pd.concat([df_ext_X_hit, df_ext_X_irr], axis=0).reset_index().iloc[:, 1:]
df_ext_y = df_ext_y.reset_index().iloc[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score

# complete 10 iterations
for seed in range(10):
    # grab a subset
    np.random.seed(seed)
    perc_train = 0.75

    # training and during training testing
    mask_hit = ~(hit['CDR3'].isin(df_ext_X['CDR3']) | hit['Epitope'].isin(df_ext_X['Epitope']))
    mask_irr = ~(irr['CDR3'].isin(df_ext_X['CDR3']) | irr['Epitope'].isin(df_ext_X['Epitope']))
    # > subset target
    idxs = np.random.choice(hit[mask_hit].index, size=sum(mask_hit), replace=False)
    idxs, idys = idxs[:round(sum(mask_hit) * perc_train)], idxs[round(sum(mask_hit) * perc_train):]
    hit_train, hit_test = hit.loc[idxs], hit.loc[idys]
    # > subset control
    idxs = np.random.choice(irr[mask_irr].index, size=sum(mask_irr), replace=False)
    idxs, idys = idxs[:round(sum(mask_irr) * perc_train)], idxs[round(sum(mask_irr) * perc_train):]
    irr_train, irr_test = irr.loc[idxs], irr.loc[idys]

    # create X for training
    X_train = pd.concat([hit_train, irr_train], axis=0).reset_index().iloc[:, 1:]
    cdr3s_training = X_train['CDR3'].unique()
    X_train_cdr3s = X_cdr3s.loc[X_train['CDR3']].reset_index().iloc[:, 1:]
    X_train_epitopes = X_epitopes.loc[X_train['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_train_cdr3s.columns = 'cdr3:' + X_train_cdr3s.columns
    X_train_epitopes.columns = 'ag:' + X_train_epitopes.columns
    X_train = X_train_cdr3s.join(X_train_epitopes)
    # grab y for training
    y_train = pd.concat([pd.Series(np.ones(hit_train.shape[0])), pd.Series(np.zeros(irr_train.shape[0]))], axis=0).astype(int)
    y_train = y_train.reset_index().iloc[:, 1:][0]

    # create X for testing
    X_test = pd.concat([hit_test, irr_test], axis=0).reset_index().iloc[:, 1:]
    X_test_cdr3s = X_cdr3s.loc[X_test['CDR3']].reset_index().iloc[:, 1:]
    X_test_epitopes = X_epitopes.loc[X_test['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_test_cdr3s.columns = 'cdr3:' + X_test_cdr3s.columns
    X_test_epitopes.columns = 'ag:' + X_test_epitopes.columns
    X_test = X_test_cdr3s.join(X_test_epitopes)
    # grab y for testing
    y_test = pd.concat([pd.Series(np.ones(hit_test.shape[0])), pd.Series(np.zeros(irr_test.shape[0]))], axis=0).astype(int)
    y_test = y_test.reset_index().iloc[:, 1:][0]

    # create X for validation
    X_val = df_ext_X.copy().reset_index().iloc[:, 1:]
    X_val_cdr3s = X_cdr3s.loc[X_val['CDR3']].reset_index().iloc[:, 1:]
    X_val_epitopes = X_epitopes.loc[X_val['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_val_cdr3s.columns = 'cdr3:' + X_val_cdr3s.columns
    X_val_epitopes.columns = 'ag:' + X_val_epitopes.columns
    X_val = X_val_cdr3s.join(X_val_epitopes)
    # grab y for validation
    y_val = df_ext_y.copy().reset_index().iloc[:, 1:][0]
    
    print(X_train.shape[0], X_val.shape[0])

    # remove constant columns
    X_train = X_train.loc[:, X_train.nunique(0) > 1]
    X_train = X_train.loc[:, X_train.sum(0) > 0]
    # read in normalization factors
    means = X_train.mean(0)
    stds = (X_train - means).std(0)
    # subset for relevant columns
    X_train = X_train[means.index]
    X_test = X_test[means.index]
    X_val = X_val.T.reindex(means.index).fillna(0).T
    # normalize
    X_train -= means
    X_train /= stds
    X_test -= means
    X_test /= stds
    X_val -= means
    X_val /= stds

    # retrieve the appropriate columns
    cols_cdr3 = X_val.columns[X_val.columns.str.startswith('cdr3')]
    cols_ag = X_val.columns[X_val.columns.str.startswith('ag')]

    # determine model parameters
    # > layer for cdr3 alone
    input_1 = keras.layers.Input(shape=(len(cols_cdr3)))
    output_1 = keras.layers.Dense(200, activation='sigmoid')(input_1)
    # > layer for ag alone
    input_2 = keras.layers.Input(shape=(len(cols_ag)))
    output_2 = keras.layers.Dense(100, activation='sigmoid')(input_2)
    # > combined layer
    concat_3 = keras.layers.Concatenate()([output_1, output_2])
    output_3 = keras.layers.Dense(100, activation='sigmoid')(concat_3)
    # > final logit softmax layer
    output_4 = keras.layers.Dense(1, activation='sigmoid')(output_3)
    model = keras.Model(inputs=[input_1, input_2], outputs=[output_4])
    # set up the training parameters for the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='binary_crossentropy',
        metrics=['accuracy','AUC'],
    )
    # train the model
    history = model.fit([X_train[cols_cdr3], X_train[cols_ag]], y_train,
                        epochs=5,
                        validation_data=([X_val[cols_cdr3], X_val[cols_ag]], y_val),
                        workers=40, use_multiprocessing=True)

    # testing predictions
    y_pred = model.predict([X_val[cols_cdr3], X_val[cols_ag]],
                           workers=40, use_multiprocessing=True)[:, 0]
    y_pred = pd.Series(y_pred, index=y_val.index, name='Pred%')
    y_pred = pd.concat([y_pred, y_val], axis=1)

    # retrieve auc metrics
    fpr, tpr, _ = roc_curve(y_pred[0], y_pred['Pred%'])
    fprs.append(fpr.tolist())
    tprs.append(tpr.tolist())
    aucs.append(auc(fpr, tpr))
    accs.append(accuracy_score(y_pred[0], y_pred['Pred%'].apply(round)))
    print(auc(fpr, tpr))
# Out:
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4902 - accuracy: 0.7686 - auc: 0.7816 - val_loss: 0.7567 - val_accuracy: 0.5546 - val_auc: 0.6667
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4386 - accuracy: 0.7948 - auc: 0.8340 - val_loss: 0.7330 - val_accuracy: 0.6018 - val_auc: 0.6847
# Epoch 3/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4002 - accuracy: 0.8170 - auc: 0.8676 - val_loss: 0.9743 - val_accuracy: 0.5666 - val_auc: 0.6692
# Epoch 4/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3548 - accuracy: 0.8434 - auc: 0.8995 - val_loss: 0.9714 - val_accuracy: 0.5845 - val_auc: 0.6710
# Epoch 5/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3066 - accuracy: 0.8679 - auc: 0.9265 - val_loss: 1.2981 - val_accuracy: 0.5798 - val_auc: 0.6672
# 675/675 [==============================] - 1s 2ms/step
# 0.6704282604040428
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4915 - accuracy: 0.7676 - auc: 0.7806 - val_loss: 0.8036 - val_accuracy: 0.5349 - val_auc: 0.6776
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4398 - accuracy: 0.7946 - auc: 0.8334 - val_loss: 0.8104 - val_accuracy: 0.5717 - val_auc: 0.6770
# Epoch 3/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4033 - accuracy: 0.8157 - auc: 0.8653 - val_loss: 0.8282 - val_accuracy: 0.5847 - val_auc: 0.6724
# Epoch 4/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3552 - accuracy: 0.8437 - auc: 0.8988 - val_loss: 1.0757 - val_accuracy: 0.5766 - val_auc: 0.6588
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3030 - accuracy: 0.8701 - auc: 0.9282 - val_loss: 1.3012 - val_accuracy: 0.5751 - val_auc: 0.6583
# 675/675 [==============================] - 2s 2ms/step
# 0.6600898831013853
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4928 - accuracy: 0.7669 - auc: 0.7795 - val_loss: 0.8123 - val_accuracy: 0.5330 - val_auc: 0.6632
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4386 - accuracy: 0.7942 - auc: 0.8346 - val_loss: 0.8045 - val_accuracy: 0.5811 - val_auc: 0.6806
# Epoch 3/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3998 - accuracy: 0.8184 - auc: 0.8679 - val_loss: 0.8388 - val_accuracy: 0.5940 - val_auc: 0.6625
# Epoch 4/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3518 - accuracy: 0.8444 - auc: 0.9013 - val_loss: 1.0097 - val_accuracy: 0.5814 - val_auc: 0.6466
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3015 - accuracy: 0.8698 - auc: 0.9289 - val_loss: 1.2856 - val_accuracy: 0.5659 - val_auc: 0.6302
# 675/675 [==============================] - 2s 2ms/step
# 0.6330411300939423
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4915 - accuracy: 0.7678 - auc: 0.7802 - val_loss: 0.7968 - val_accuracy: 0.5570 - val_auc: 0.6692
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4392 - accuracy: 0.7949 - auc: 0.8333 - val_loss: 0.8276 - val_accuracy: 0.5720 - val_auc: 0.6693
# Epoch 3/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4014 - accuracy: 0.8166 - auc: 0.8660 - val_loss: 1.0023 - val_accuracy: 0.5784 - val_auc: 0.6737
# Epoch 4/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3525 - accuracy: 0.8449 - auc: 0.9002 - val_loss: 1.0558 - val_accuracy: 0.5817 - val_auc: 0.6710
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3016 - accuracy: 0.8709 - auc: 0.9288 - val_loss: 1.2650 - val_accuracy: 0.5769 - val_auc: 0.6669
# 675/675 [==============================] - 2s 2ms/step
# 0.6696701728507637
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4938 - accuracy: 0.7675 - auc: 0.7778 - val_loss: 0.9073 - val_accuracy: 0.5182 - val_auc: 0.6866
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4418 - accuracy: 0.7910 - auc: 0.8312 - val_loss: 0.9164 - val_accuracy: 0.5583 - val_auc: 0.6877
# Epoch 3/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4021 - accuracy: 0.8170 - auc: 0.8662 - val_loss: 0.9377 - val_accuracy: 0.5858 - val_auc: 0.6820
# Epoch 4/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3511 - accuracy: 0.8455 - auc: 0.9014 - val_loss: 1.1241 - val_accuracy: 0.5876 - val_auc: 0.6685
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2990 - accuracy: 0.8719 - auc: 0.9298 - val_loss: 1.7974 - val_accuracy: 0.5480 - val_auc: 0.6412
# 675/675 [==============================] - 2s 2ms/step
# 0.6525148344861283
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4914 - accuracy: 0.7684 - auc: 0.7798 - val_loss: 0.9619 - val_accuracy: 0.5183 - val_auc: 0.6716
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4403 - accuracy: 0.7935 - auc: 0.8328 - val_loss: 0.7855 - val_accuracy: 0.5687 - val_auc: 0.6657
# Epoch 3/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4004 - accuracy: 0.8187 - auc: 0.8672 - val_loss: 0.9246 - val_accuracy: 0.5773 - val_auc: 0.6858
# Epoch 4/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3480 - accuracy: 0.8474 - auc: 0.9029 - val_loss: 1.0632 - val_accuracy: 0.5733 - val_auc: 0.6552
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2970 - accuracy: 0.8731 - auc: 0.9307 - val_loss: 1.2085 - val_accuracy: 0.5755 - val_auc: 0.6673
# 675/675 [==============================] - 2s 2ms/step
# 0.6697720988209145
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 16s 4ms/step - loss: 0.4914 - accuracy: 0.7674 - auc: 0.7810 - val_loss: 0.7073 - val_accuracy: 0.6086 - val_auc: 0.6701
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4393 - accuracy: 0.7937 - auc: 0.8342 - val_loss: 0.7784 - val_accuracy: 0.5755 - val_auc: 0.6745
# Epoch 3/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4004 - accuracy: 0.8182 - auc: 0.8670 - val_loss: 0.8704 - val_accuracy: 0.5766 - val_auc: 0.6609
# Epoch 4/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3529 - accuracy: 0.8449 - auc: 0.8999 - val_loss: 0.9914 - val_accuracy: 0.5564 - val_auc: 0.6152
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3022 - accuracy: 0.8696 - auc: 0.9282 - val_loss: 1.2388 - val_accuracy: 0.5595 - val_auc: 0.6321
# 675/675 [==============================] - 2s 2ms/step
# 0.6346206369666776
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4918 - accuracy: 0.7674 - auc: 0.7808 - val_loss: 0.7074 - val_accuracy: 0.5846 - val_auc: 0.6342
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4395 - accuracy: 0.7937 - auc: 0.8337 - val_loss: 0.8113 - val_accuracy: 0.5702 - val_auc: 0.6704
# Epoch 3/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4009 - accuracy: 0.8167 - auc: 0.8668 - val_loss: 0.8427 - val_accuracy: 0.5867 - val_auc: 0.6589
# Epoch 4/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3549 - accuracy: 0.8431 - auc: 0.8986 - val_loss: 1.0179 - val_accuracy: 0.5861 - val_auc: 0.6705
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3043 - accuracy: 0.8685 - auc: 0.9272 - val_loss: 1.1039 - val_accuracy: 0.5807 - val_auc: 0.6720
# 675/675 [==============================] - 2s 2ms/step
# 0.6728990666669357
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4925 - accuracy: 0.7674 - auc: 0.7788 - val_loss: 0.8043 - val_accuracy: 0.5552 - val_auc: 0.6818
# Epoch 2/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4391 - accuracy: 0.7949 - auc: 0.8337 - val_loss: 0.7219 - val_accuracy: 0.5872 - val_auc: 0.6507
# Epoch 3/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3976 - accuracy: 0.8201 - auc: 0.8691 - val_loss: 0.9099 - val_accuracy: 0.5757 - val_auc: 0.6438
# Epoch 4/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3467 - accuracy: 0.8487 - auc: 0.9039 - val_loss: 1.0615 - val_accuracy: 0.5707 - val_auc: 0.6271
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2949 - accuracy: 0.8741 - auc: 0.9318 - val_loss: 1.1172 - val_accuracy: 0.5744 - val_auc: 0.6199
# 675/675 [==============================] - 2s 2ms/step
# 0.6216231885725774
# 109785 21596
# Epoch 1/5
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4916 - accuracy: 0.7682 - auc: 0.7814 - val_loss: 0.8687 - val_accuracy: 0.5532 - val_auc: 0.6798
# Epoch 2/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4402 - accuracy: 0.7936 - auc: 0.8333 - val_loss: 0.9479 - val_accuracy: 0.5538 - val_auc: 0.6733
# Epoch 3/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4017 - accuracy: 0.8171 - auc: 0.8667 - val_loss: 0.8753 - val_accuracy: 0.5845 - val_auc: 0.6621
# Epoch 4/5
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3536 - accuracy: 0.8444 - auc: 0.8999 - val_loss: 0.9633 - val_accuracy: 0.5755 - val_auc: 0.6609
# Epoch 5/5
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3041 - accuracy: 0.8698 - auc: 0.9278 - val_loss: 1.2387 - val_accuracy: 0.5842 - val_auc: 0.6649
# 675/675 [==============================] - 2s 2ms/step
# 0.6677048527574009

# %%
# create roc auc curve
fig, ax = plt.subplots(figsize=[4, 4])
ax.grid(False)
# track values to compute mean value
mean_tprs, mean_fpr = [], np.linspace(0, 1, 100)
# plot the individual cv iterations
for fpr, tpr in zip(fprs, tprs):
    # grab the true positive rate when we interpolate
    mean_tprs.append(np.interp(mean_fpr, fpr, tpr))
#     # plot on this individual curve
#     ax.plot(fpr, tpr, color='tab:blue', linestyle='--', linewidth=1, alpha=0.5, zorder=1)
# grab metrics for auc
mean_auc = np.mean(aucs)
ci95_auc = 1.96 * np.std(aucs) / np.sqrt(len(aucs))
# grab metrics for acc
mean_acc = np.mean(accs)
ci95_acc = 1.96 * np.std(accs) / np.sqrt(len(accs))
# plot the average iteration
mean_tpr = np.mean(mean_tprs, axis=0)
ax.plot(mean_fpr, mean_tpr, color='#2D9FC4', linewidth=2,
        label=r'AUC=%0.4f$\pm$%0.4f' % (mean_auc, ci95_auc) + '\n' +
        r'ACC=%0.4f$\pm$%0.4f' % (mean_acc, ci95_acc))
# plot the standard errors (95% CI actually)
ci95_tpr = 1.96 * np.std(mean_tprs, axis=0) / np.sqrt(len(mean_tprs))
mean_tprs_upper = np.minimum(mean_tpr + ci95_tpr, 1)
mean_tprs_lower = np.maximum(mean_tpr - ci95_tpr, 0)
ax.fill_between(mean_fpr, mean_tprs_lower, mean_tprs_upper, color='#2D9FC4', alpha=0.50)
# plot the random line
ax.plot([0,1], [0,1], color='r', linewidth=2, linestyle='--', label='Random')
# add on labels and adjust limits
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.legend(bbox_to_anchor=(1.05,0.99), bbox_transform=ax.transAxes)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
# Out:
# [Text(0.5, 0, 'False Positive Rate'), Text(0, 0.5, 'True Positive Rate')]

# %%
# retrieve values and aucs
fprs, tprs, aucs, accs = [], [], [], []

# %%
# assemble hold out
df_ext_X_hit = hit.loc[hit['Epitope'] == 'GLCTLVAML']
df_ext_X_irr = irr.loc[irr['Epitope'] == 'GLCTLVAML']
df_ext_y = pd.concat([pd.Series(np.ones(df_ext_X_hit.shape[0]), index=df_ext_X_hit),
                      pd.Series(np.zeros(df_ext_X_irr.shape[0]), index=df_ext_X_irr)], axis=0)
df_ext_X = pd.concat([df_ext_X_hit, df_ext_X_irr], axis=0).reset_index().iloc[:, 1:]
df_ext_y = df_ext_y.reset_index().iloc[:, 1]

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score

# complete 10 iterations
for seed in range(10):
    # grab a subset
    np.random.seed(seed)
    perc_train = 0.75

    # training and during training testing
    mask_hit = ~(hit['CDR3'].isin(df_ext_X['CDR3']) | hit['Epitope'].isin(df_ext_X['Epitope']))
    mask_irr = ~(irr['CDR3'].isin(df_ext_X['CDR3']) | irr['Epitope'].isin(df_ext_X['Epitope']))
    # > subset target
    idxs = np.random.choice(hit[mask_hit].index, size=sum(mask_hit), replace=False)
    idxs, idys = idxs[:round(sum(mask_hit) * perc_train)], idxs[round(sum(mask_hit) * perc_train):]
    hit_train, hit_test = hit.loc[idxs], hit.loc[idys]
    # > subset control
    idxs = np.random.choice(irr[mask_irr].index, size=sum(mask_irr), replace=False)
    idxs, idys = idxs[:round(sum(mask_irr) * perc_train)], idxs[round(sum(mask_irr) * perc_train):]
    irr_train, irr_test = irr.loc[idxs], irr.loc[idys]

    # create X for training
    X_train = pd.concat([hit_train, irr_train], axis=0).reset_index().iloc[:, 1:]
    cdr3s_training = X_train['CDR3'].unique()
    X_train_cdr3s = X_cdr3s.loc[X_train['CDR3']].reset_index().iloc[:, 1:]
    X_train_epitopes = X_epitopes.loc[X_train['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_train_cdr3s.columns = 'cdr3:' + X_train_cdr3s.columns
    X_train_epitopes.columns = 'ag:' + X_train_epitopes.columns
    X_train = X_train_cdr3s.join(X_train_epitopes)
    # grab y for training
    y_train = pd.concat([pd.Series(np.ones(hit_train.shape[0])), pd.Series(np.zeros(irr_train.shape[0]))], axis=0).astype(int)
    y_train = y_train.reset_index().iloc[:, 1:][0]

    # create X for testing
    X_test = pd.concat([hit_test, irr_test], axis=0).reset_index().iloc[:, 1:]
    X_test_cdr3s = X_cdr3s.loc[X_test['CDR3']].reset_index().iloc[:, 1:]
    X_test_epitopes = X_epitopes.loc[X_test['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_test_cdr3s.columns = 'cdr3:' + X_test_cdr3s.columns
    X_test_epitopes.columns = 'ag:' + X_test_epitopes.columns
    X_test = X_test_cdr3s.join(X_test_epitopes)
    # grab y for testing
    y_test = pd.concat([pd.Series(np.ones(hit_test.shape[0])), pd.Series(np.zeros(irr_test.shape[0]))], axis=0).astype(int)
    y_test = y_test.reset_index().iloc[:, 1:][0]

    # create X for validation
    X_val = df_ext_X.copy().reset_index().iloc[:, 1:]
    X_val_cdr3s = X_cdr3s.loc[X_val['CDR3']].reset_index().iloc[:, 1:]
    X_val_epitopes = X_epitopes.loc[X_val['Epitope']].reset_index().iloc[:, 1:]
    # combine
    X_val_cdr3s.columns = 'cdr3:' + X_val_cdr3s.columns
    X_val_epitopes.columns = 'ag:' + X_val_epitopes.columns
    X_val = X_val_cdr3s.join(X_val_epitopes)
    # grab y for validation
    y_val = df_ext_y.copy().reset_index().iloc[:, 1:][0]
    
    print(X_train.shape[0], X_val.shape[0])

    # remove constant columns
    X_train = X_train.loc[:, X_train.nunique(0) > 1]
    X_train = X_train.loc[:, X_train.sum(0) > 0]
    # read in normalization factors
    means = X_train.mean(0)
    stds = (X_train - means).std(0)
    # subset for relevant columns
    X_train = X_train[means.index]
    X_test = X_test[means.index]
    X_val = X_val.T.reindex(means.index).fillna(0).T
    # normalize
    X_train -= means
    X_train /= stds
    X_test -= means
    X_test /= stds
    X_val -= means
    X_val /= stds

    # retrieve the appropriate columns
    cols_cdr3 = X_val.columns[X_val.columns.str.startswith('cdr3')]
    cols_ag = X_val.columns[X_val.columns.str.startswith('ag')]

    # determine model parameters
    # > layer for cdr3 alone
    input_1 = keras.layers.Input(shape=(len(cols_cdr3)))
    output_1 = keras.layers.Dense(200, activation='sigmoid')(input_1)
    # > layer for ag alone
    input_2 = keras.layers.Input(shape=(len(cols_ag)))
    output_2 = keras.layers.Dense(100, activation='sigmoid')(input_2)
    # > combined layer
    concat_3 = keras.layers.Concatenate()([output_1, output_2])
    output_3 = keras.layers.Dense(100, activation='sigmoid')(concat_3)
    # > final logit softmax layer
    output_4 = keras.layers.Dense(1, activation='sigmoid')(output_3)
    model = keras.Model(inputs=[input_1, input_2], outputs=[output_4])
    # set up the training parameters for the model
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='binary_crossentropy',
        metrics=['accuracy','AUC'],
    )
    # train the model
    history = model.fit([X_train[cols_cdr3], X_train[cols_ag]], y_train,
                        epochs=10,
                        validation_data=([X_val[cols_cdr3], X_val[cols_ag]], y_val),
                        workers=40, use_multiprocessing=True)

    # testing predictions
    y_pred = model.predict([X_val[cols_cdr3], X_val[cols_ag]],
                           workers=40, use_multiprocessing=True)[:, 0]
    y_pred = pd.Series(y_pred, index=y_val.index, name='Pred%')
    y_pred = pd.concat([y_pred, y_val], axis=1)

    # retrieve auc metrics
    fpr, tpr, _ = roc_curve(y_pred[0], y_pred['Pred%'])
    fprs.append(fpr.tolist())
    tprs.append(tpr.tolist())
    aucs.append(auc(fpr, tpr))
    accs.append(accuracy_score(y_pred[0], y_pred['Pred%'].apply(round)))
    print(auc(fpr, tpr))
# Out:
# 109785 21596
# 2023-11-01 13:32:03.874982: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-01 13:32:03.875013: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-01 13:32:03.875394: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4909 - accuracy: 0.7686 - auc: 0.7809 - val_loss: 0.7513 - val_accuracy: 0.5676 - val_auc: 0.6688
# Epoch 2/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4378 - accuracy: 0.7953 - auc: 0.8350 - val_loss: 0.7219 - val_accuracy: 0.5943 - val_auc: 0.6586
# Epoch 3/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3988 - accuracy: 0.8178 - auc: 0.8686 - val_loss: 0.8472 - val_accuracy: 0.5841 - val_auc: 0.6547
# Epoch 4/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3512 - accuracy: 0.8450 - auc: 0.9013 - val_loss: 1.0277 - val_accuracy: 0.5877 - val_auc: 0.6467
# Epoch 5/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3022 - accuracy: 0.8700 - auc: 0.9288 - val_loss: 1.1476 - val_accuracy: 0.5904 - val_auc: 0.6455
# Epoch 6/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2575 - accuracy: 0.8912 - auc: 0.9488 - val_loss: 1.5222 - val_accuracy: 0.5837 - val_auc: 0.6401
# Epoch 7/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2228 - accuracy: 0.9071 - auc: 0.9618 - val_loss: 1.6893 - val_accuracy: 0.5790 - val_auc: 0.6275
# Epoch 8/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1941 - accuracy: 0.9202 - auc: 0.9712 - val_loss: 1.9402 - val_accuracy: 0.5763 - val_auc: 0.6215
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1701 - accuracy: 0.9307 - auc: 0.9779 - val_loss: 1.9764 - val_accuracy: 0.5748 - val_auc: 0.6090
# Epoch 10/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1514 - accuracy: 0.9386 - auc: 0.9825 - val_loss: 1.8420 - val_accuracy: 0.5718 - val_auc: 0.6068
# 675/675 [==============================] - 2s 2ms/step
# 0.6209735838819131
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4918 - accuracy: 0.7685 - auc: 0.7789 - val_loss: 0.8409 - val_accuracy: 0.5200 - val_auc: 0.6729
# Epoch 2/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4405 - accuracy: 0.7936 - auc: 0.8314 - val_loss: 0.8189 - val_accuracy: 0.5798 - val_auc: 0.6774
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4026 - accuracy: 0.8164 - auc: 0.8646 - val_loss: 0.8258 - val_accuracy: 0.5959 - val_auc: 0.6845
# Epoch 4/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3544 - accuracy: 0.8447 - auc: 0.8987 - val_loss: 1.0004 - val_accuracy: 0.5944 - val_auc: 0.6808
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3031 - accuracy: 0.8715 - auc: 0.9280 - val_loss: 1.1994 - val_accuracy: 0.5836 - val_auc: 0.6685
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2589 - accuracy: 0.8904 - auc: 0.9478 - val_loss: 1.6429 - val_accuracy: 0.5785 - val_auc: 0.6481
# Epoch 7/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2237 - accuracy: 0.9059 - auc: 0.9613 - val_loss: 1.4932 - val_accuracy: 0.5845 - val_auc: 0.6449
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1936 - accuracy: 0.9192 - auc: 0.9712 - val_loss: 1.5986 - val_accuracy: 0.5898 - val_auc: 0.6470
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1697 - accuracy: 0.9300 - auc: 0.9780 - val_loss: 1.6255 - val_accuracy: 0.5847 - val_auc: 0.6259
# Epoch 10/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1498 - accuracy: 0.9388 - auc: 0.9829 - val_loss: 1.9962 - val_accuracy: 0.5699 - val_auc: 0.6120
# 675/675 [==============================] - 2s 2ms/step
# 0.6226655369517389
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4935 - accuracy: 0.7679 - auc: 0.7791 - val_loss: 0.8726 - val_accuracy: 0.5203 - val_auc: 0.6681
# Epoch 2/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4372 - accuracy: 0.7949 - auc: 0.8361 - val_loss: 0.8810 - val_accuracy: 0.5659 - val_auc: 0.6659
# Epoch 3/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3962 - accuracy: 0.8199 - auc: 0.8704 - val_loss: 0.9121 - val_accuracy: 0.5764 - val_auc: 0.6446
# Epoch 4/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3473 - accuracy: 0.8471 - auc: 0.9038 - val_loss: 1.0405 - val_accuracy: 0.5836 - val_auc: 0.6520
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2950 - accuracy: 0.8746 - auc: 0.9320 - val_loss: 1.2165 - val_accuracy: 0.5710 - val_auc: 0.6223
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2516 - accuracy: 0.8944 - auc: 0.9510 - val_loss: 1.4855 - val_accuracy: 0.5756 - val_auc: 0.6231
# Epoch 7/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2160 - accuracy: 0.9103 - auc: 0.9642 - val_loss: 1.7510 - val_accuracy: 0.5722 - val_auc: 0.6154
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1888 - accuracy: 0.9224 - auc: 0.9726 - val_loss: 1.8737 - val_accuracy: 0.5772 - val_auc: 0.6289
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1645 - accuracy: 0.9338 - auc: 0.9793 - val_loss: 2.4660 - val_accuracy: 0.5546 - val_auc: 0.5958
# Epoch 10/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1456 - accuracy: 0.9418 - auc: 0.9838 - val_loss: 2.4955 - val_accuracy: 0.5651 - val_auc: 0.6067
# 675/675 [==============================] - 2s 2ms/step
# 0.6376966310926981
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4946 - accuracy: 0.7663 - auc: 0.7777 - val_loss: 0.8997 - val_accuracy: 0.5228 - val_auc: 0.6904
# Epoch 2/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4401 - accuracy: 0.7939 - auc: 0.8328 - val_loss: 0.8437 - val_accuracy: 0.5617 - val_auc: 0.6847
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3996 - accuracy: 0.8188 - auc: 0.8672 - val_loss: 0.9711 - val_accuracy: 0.5716 - val_auc: 0.6801
# Epoch 4/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3511 - accuracy: 0.8460 - auc: 0.9013 - val_loss: 1.1995 - val_accuracy: 0.5682 - val_auc: 0.6639
# Epoch 5/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3017 - accuracy: 0.8713 - auc: 0.9287 - val_loss: 1.3739 - val_accuracy: 0.5797 - val_auc: 0.6675
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2595 - accuracy: 0.8909 - auc: 0.9475 - val_loss: 1.8366 - val_accuracy: 0.5628 - val_auc: 0.6497
# Epoch 7/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2242 - accuracy: 0.9071 - auc: 0.9610 - val_loss: 2.3311 - val_accuracy: 0.5629 - val_auc: 0.6295
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1976 - accuracy: 0.9186 - auc: 0.9697 - val_loss: 2.1242 - val_accuracy: 0.5683 - val_auc: 0.6164
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1738 - accuracy: 0.9286 - auc: 0.9768 - val_loss: 2.4899 - val_accuracy: 0.5721 - val_auc: 0.6261
# Epoch 10/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1544 - accuracy: 0.9370 - auc: 0.9818 - val_loss: 3.0782 - val_accuracy: 0.5609 - val_auc: 0.5988
# 675/675 [==============================] - 2s 2ms/step
# 0.6357453651637327
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4951 - accuracy: 0.7652 - auc: 0.7772 - val_loss: 0.8835 - val_accuracy: 0.5182 - val_auc: 0.6685
# Epoch 2/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4413 - accuracy: 0.7928 - auc: 0.8318 - val_loss: 0.8459 - val_accuracy: 0.5733 - val_auc: 0.6870
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4018 - accuracy: 0.8153 - auc: 0.8662 - val_loss: 0.9194 - val_accuracy: 0.5763 - val_auc: 0.6765
# Epoch 4/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3533 - accuracy: 0.8449 - auc: 0.8999 - val_loss: 1.1629 - val_accuracy: 0.5573 - val_auc: 0.6480
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3026 - accuracy: 0.8699 - auc: 0.9283 - val_loss: 1.3326 - val_accuracy: 0.5656 - val_auc: 0.6562
# Epoch 6/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2592 - accuracy: 0.8901 - auc: 0.9479 - val_loss: 1.6294 - val_accuracy: 0.5553 - val_auc: 0.6345
# Epoch 7/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2229 - accuracy: 0.9068 - auc: 0.9617 - val_loss: 2.1726 - val_accuracy: 0.5565 - val_auc: 0.6360
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1943 - accuracy: 0.9205 - auc: 0.9709 - val_loss: 2.4506 - val_accuracy: 0.5506 - val_auc: 0.6010
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1712 - accuracy: 0.9303 - auc: 0.9775 - val_loss: 2.6473 - val_accuracy: 0.5545 - val_auc: 0.6097
# Epoch 10/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1507 - accuracy: 0.9392 - auc: 0.9827 - val_loss: 2.8159 - val_accuracy: 0.5551 - val_auc: 0.6021
# 675/675 [==============================] - 2s 2ms/step
# 0.6499067800543883
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4919 - accuracy: 0.7675 - auc: 0.7803 - val_loss: 0.8243 - val_accuracy: 0.5370 - val_auc: 0.6575
# Epoch 2/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4379 - accuracy: 0.7950 - auc: 0.8353 - val_loss: 0.7693 - val_accuracy: 0.5900 - val_auc: 0.6704
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3989 - accuracy: 0.8178 - auc: 0.8680 - val_loss: 0.8325 - val_accuracy: 0.5916 - val_auc: 0.6552
# Epoch 4/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3514 - accuracy: 0.8454 - auc: 0.9009 - val_loss: 0.9273 - val_accuracy: 0.5896 - val_auc: 0.6552
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3007 - accuracy: 0.8710 - auc: 0.9288 - val_loss: 1.3283 - val_accuracy: 0.5749 - val_auc: 0.6573
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2581 - accuracy: 0.8913 - auc: 0.9480 - val_loss: 1.2378 - val_accuracy: 0.5922 - val_auc: 0.6524
# Epoch 7/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2217 - accuracy: 0.9064 - auc: 0.9619 - val_loss: 1.6760 - val_accuracy: 0.5764 - val_auc: 0.6382
# Epoch 8/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1942 - accuracy: 0.9196 - auc: 0.9708 - val_loss: 1.8963 - val_accuracy: 0.5837 - val_auc: 0.6415
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1694 - accuracy: 0.9305 - auc: 0.9779 - val_loss: 2.0608 - val_accuracy: 0.5844 - val_auc: 0.6343
# Epoch 10/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1509 - accuracy: 0.9379 - auc: 0.9825 - val_loss: 2.2257 - val_accuracy: 0.5740 - val_auc: 0.6334
# 675/675 [==============================] - 2s 2ms/step
# 0.651921278988217
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4915 - accuracy: 0.7675 - auc: 0.7808 - val_loss: 0.7164 - val_accuracy: 0.6005 - val_auc: 0.6666
# Epoch 2/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4382 - accuracy: 0.7956 - auc: 0.8343 - val_loss: 0.7594 - val_accuracy: 0.5977 - val_auc: 0.6702
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3965 - accuracy: 0.8207 - auc: 0.8701 - val_loss: 0.8553 - val_accuracy: 0.5840 - val_auc: 0.6422
# Epoch 4/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3438 - accuracy: 0.8500 - auc: 0.9057 - val_loss: 1.1305 - val_accuracy: 0.5717 - val_auc: 0.6389
# Epoch 5/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2912 - accuracy: 0.8755 - auc: 0.9340 - val_loss: 1.3970 - val_accuracy: 0.5570 - val_auc: 0.6393
# Epoch 6/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2482 - accuracy: 0.8953 - auc: 0.9524 - val_loss: 1.5432 - val_accuracy: 0.5585 - val_auc: 0.6193
# Epoch 7/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.2146 - accuracy: 0.9109 - auc: 0.9645 - val_loss: 1.7064 - val_accuracy: 0.5724 - val_auc: 0.6233
# Epoch 8/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1869 - accuracy: 0.9227 - auc: 0.9733 - val_loss: 1.7708 - val_accuracy: 0.5704 - val_auc: 0.6200
# Epoch 9/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1641 - accuracy: 0.9331 - auc: 0.9794 - val_loss: 2.0775 - val_accuracy: 0.5679 - val_auc: 0.6077
# Epoch 10/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1452 - accuracy: 0.9412 - auc: 0.9840 - val_loss: 1.9039 - val_accuracy: 0.5780 - val_auc: 0.6115
# 675/675 [==============================] - 2s 2ms/step
# 0.6269496868214319
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4940 - accuracy: 0.7660 - auc: 0.7798 - val_loss: 0.7830 - val_accuracy: 0.5491 - val_auc: 0.6795
# Epoch 2/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4393 - accuracy: 0.7928 - auc: 0.8347 - val_loss: 0.8144 - val_accuracy: 0.5701 - val_auc: 0.6768
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4000 - accuracy: 0.8166 - auc: 0.8680 - val_loss: 0.8079 - val_accuracy: 0.6031 - val_auc: 0.6636
# Epoch 4/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3502 - accuracy: 0.8453 - auc: 0.9017 - val_loss: 1.0396 - val_accuracy: 0.5860 - val_auc: 0.6670
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.3001 - accuracy: 0.8716 - auc: 0.9291 - val_loss: 1.4347 - val_accuracy: 0.5745 - val_auc: 0.6579
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2575 - accuracy: 0.8903 - auc: 0.9482 - val_loss: 1.4100 - val_accuracy: 0.5949 - val_auc: 0.6522
# Epoch 7/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2230 - accuracy: 0.9061 - auc: 0.9614 - val_loss: 1.7033 - val_accuracy: 0.5816 - val_auc: 0.6340
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1932 - accuracy: 0.9190 - auc: 0.9713 - val_loss: 1.9285 - val_accuracy: 0.5844 - val_auc: 0.6368
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1706 - accuracy: 0.9298 - auc: 0.9778 - val_loss: 2.1733 - val_accuracy: 0.5764 - val_auc: 0.6209
# Epoch 10/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.1511 - accuracy: 0.9381 - auc: 0.9826 - val_loss: 2.2568 - val_accuracy: 0.5733 - val_auc: 0.6043
# 675/675 [==============================] - 2s 2ms/step
# 0.6257080381103595
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4927 - accuracy: 0.7681 - auc: 0.7788 - val_loss: 0.8303 - val_accuracy: 0.5423 - val_auc: 0.6797
# Epoch 2/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4385 - accuracy: 0.7959 - auc: 0.8342 - val_loss: 0.8101 - val_accuracy: 0.5718 - val_auc: 0.6667
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3974 - accuracy: 0.8202 - auc: 0.8697 - val_loss: 1.1000 - val_accuracy: 0.5553 - val_auc: 0.6534
# Epoch 4/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3468 - accuracy: 0.8483 - auc: 0.9038 - val_loss: 1.0415 - val_accuracy: 0.5746 - val_auc: 0.6478
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2967 - accuracy: 0.8738 - auc: 0.9311 - val_loss: 1.4228 - val_accuracy: 0.5611 - val_auc: 0.6303
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2545 - accuracy: 0.8934 - auc: 0.9497 - val_loss: 1.4086 - val_accuracy: 0.5707 - val_auc: 0.6184
# Epoch 7/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2201 - accuracy: 0.9074 - auc: 0.9626 - val_loss: 1.4946 - val_accuracy: 0.5658 - val_auc: 0.6047
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1909 - accuracy: 0.9210 - auc: 0.9720 - val_loss: 1.9653 - val_accuracy: 0.5653 - val_auc: 0.6075
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1671 - accuracy: 0.9317 - auc: 0.9786 - val_loss: 2.5086 - val_accuracy: 0.5512 - val_auc: 0.5933
# Epoch 10/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1472 - accuracy: 0.9404 - auc: 0.9834 - val_loss: 2.4281 - val_accuracy: 0.5559 - val_auc: 0.5913
# 675/675 [==============================] - 1s 2ms/step
# 0.6102523905498132
# 109785 21596
# Epoch 1/10
# 3431/3431 [==============================] - 15s 4ms/step - loss: 0.4934 - accuracy: 0.7661 - auc: 0.7778 - val_loss: 0.8095 - val_accuracy: 0.5289 - val_auc: 0.6588
# Epoch 2/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.4398 - accuracy: 0.7947 - auc: 0.8331 - val_loss: 0.9070 - val_accuracy: 0.5594 - val_auc: 0.6770
# Epoch 3/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.4004 - accuracy: 0.8168 - auc: 0.8672 - val_loss: 1.0473 - val_accuracy: 0.5539 - val_auc: 0.6629
# Epoch 4/10
# 3431/3431 [==============================] - 13s 4ms/step - loss: 0.3502 - accuracy: 0.8459 - auc: 0.9017 - val_loss: 0.9936 - val_accuracy: 0.5757 - val_auc: 0.6537
# Epoch 5/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2995 - accuracy: 0.8701 - auc: 0.9294 - val_loss: 1.2427 - val_accuracy: 0.5658 - val_auc: 0.6307
# Epoch 6/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2564 - accuracy: 0.8911 - auc: 0.9488 - val_loss: 1.5341 - val_accuracy: 0.5695 - val_auc: 0.6286
# Epoch 7/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.2211 - accuracy: 0.9073 - auc: 0.9621 - val_loss: 1.9726 - val_accuracy: 0.5636 - val_auc: 0.6253
# Epoch 8/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1943 - accuracy: 0.9198 - auc: 0.9708 - val_loss: 2.0956 - val_accuracy: 0.5679 - val_auc: 0.6071
# Epoch 9/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1708 - accuracy: 0.9293 - auc: 0.9776 - val_loss: 2.3512 - val_accuracy: 0.5579 - val_auc: 0.5910
# Epoch 10/10
# 3431/3431 [==============================] - 14s 4ms/step - loss: 0.1508 - accuracy: 0.9381 - auc: 0.9827 - val_loss: 2.9428 - val_accuracy: 0.5516 - val_auc: 0.5757
# 675/675 [==============================] - 2s 2ms/step
# 0.6123099923563037

# %%
# create roc auc curve
fig, ax = plt.subplots(figsize=[4, 4])
ax.grid(False)
# track values to compute mean value
mean_tprs, mean_fpr = [], np.linspace(0, 1, 100)
# plot the individual cv iterations
for fpr, tpr in zip(fprs, tprs):
    # grab the true positive rate when we interpolate
    mean_tprs.append(np.interp(mean_fpr, fpr, tpr))
#     # plot on this individual curve
#     ax.plot(fpr, tpr, color='tab:blue', linestyle='--', linewidth=1, alpha=0.5, zorder=1)
# grab metrics for auc
mean_auc = np.mean(aucs)
ci95_auc = 1.96 * np.std(aucs) / np.sqrt(len(aucs))
# grab metrics for acc
mean_acc = np.mean(accs)
ci95_acc = 1.96 * np.std(accs) / np.sqrt(len(accs))
# plot the average iteration
mean_tpr = np.mean(mean_tprs, axis=0)
ax.plot(mean_fpr, mean_tpr, color='#2D9FC4', linewidth=2,
        label=r'AUC=%0.4f$\pm$%0.4f' % (mean_auc, ci95_auc) + '\n' +
        r'ACC=%0.4f$\pm$%0.4f' % (mean_acc, ci95_acc))
# plot the standard errors (95% CI actually)
ci95_tpr = 1.96 * np.std(mean_tprs, axis=0) / np.sqrt(len(mean_tprs))
mean_tprs_upper = np.minimum(mean_tpr + ci95_tpr, 1)
mean_tprs_lower = np.maximum(mean_tpr - ci95_tpr, 0)
ax.fill_between(mean_fpr, mean_tprs_lower, mean_tprs_upper, color='#2D9FC4', alpha=0.50)
# plot the random line
ax.plot([0,1], [0,1], color='r', linewidth=2, linestyle='--', label='Random')
# add on labels and adjust limits
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.legend(bbox_to_anchor=(1.05,0.99), bbox_transform=ax.transAxes)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
# Out:
# [Text(0.5, 0, 'False Positive Rate'), Text(0, 0.5, 'True Positive Rate')]
